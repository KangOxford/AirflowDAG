# %%
# !sudo apt-get install docker-engine -y
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Package docker-engine is not available, but is referred to by another package.
# This may mean that the package is missing, has been obsoleted, or
# is only available from another source
# However the following packages replace it:
#   docker-ce
#
# E: Package 'docker-engine' has no installation candidate

# %%
# !wget "https://desktop.docker.com/linux/main/amd64/docker-desktop-4.8.1-amd64.deb?utm_source=docker&utm_medium=webreferral&utm_campaign=docs-driven-download-linux-amd64"
# Out:
# --2022-05-28 00:14:43--  https://desktop.docker.com/linux/main/amd64/docker-desktop-4.8.1-amd64.deb?utm_source=docker&utm_medium=webreferral&utm_campaign=docs-driven-download-linux-amd64
# Resolving desktop.docker.com (desktop.docker.com)... 99.86.4.36, 99.86.4.71, 99.86.4.117, ...
# Connecting to desktop.docker.com (desktop.docker.com)|99.86.4.36|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 388679164 (371M)
# Saving to: ‘docker-desktop-4.8.1-amd64.deb?utm_source=docker&utm_medium=webreferral&utm_campaign=docs-driven-download-linux-amd64’
#
# docker-desktop-4.8. 100%[===================>] 370.67M  92.4MB/s    in 4.1s
#
# 2022-05-28 00:14:47 (90.7 MB/s) - ‘docker-desktop-4.8.1-amd64.deb?utm_source=docker&utm_medium=webreferral&utm_campaign=docs-driven-download-linux-amd64’ saved [388679164/388679164]

# %%
# !ls
# Out:
# airflow-tutorial  bash.sh			  README.md
# bash.ipynb	  docker-desktop-4.8.1-amd64.deb

# %%
# !sudo dpkg -i docker-desktop-4.8.1-amd64.deb
# Out:
# Selecting previously unselected package docker-desktop.
# (Reading database ... 36033 files and directories currently installed.)
# Preparing to unpack docker-desktop-4.8.1-amd64.deb ...
# Unpacking docker-desktop (4.8.1-78998) ...
# dpkg: dependency problems prevent configuration of docker-desktop:
#  docker-desktop depends on qemu-system-x86 (>= 5.2.0); however:
#   Package qemu-system-x86 is not installed.
#  docker-desktop depends on docker-ce-cli; however:
#   Package docker-ce-cli is not installed.
#  docker-desktop depends on pass; however:
#   Package pass is not installed.
#  docker-desktop depends on desktop-file-utils; however:
#   Package desktop-file-utils is not installed.
#  docker-desktop depends on libgtk-3-0; however:
#   Package libgtk-3-0 is not installed.
#  docker-desktop depends on libx11-xcb1; however:
#   Package libx11-xcb1 is not installed.
#
# dpkg: error processing package docker-desktop (--install):
#  dependency problems - leaving unconfigured
# Processing triggers for mime-support (3.64ubuntu1) ...
# Errors were encountered while processing:
#  docker-desktop

# %%
# !sudo apt --fix-broken install
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Correcting dependencies... Done
# The following additional packages will be installed:
#   acl adwaita-icon-theme at-spi2-core cpu-checker desktop-file-utils
#   docker-ce-cli docker-scan-plugin gstreamer1.0-plugins-base
#   gstreamer1.0-plugins-good gstreamer1.0-x gtk-update-icon-cache
#   humanity-icon-theme ibverbs-providers ipxe-qemu
#   ipxe-qemu-256k-compat-efi-roms libaa1 libaio1 libasyncns0 libatk-bridge2.0-0
#   libatk1.0-0 libatk1.0-data libatspi2.0-0 libavahi-client3
#   libavahi-common-data libavahi-common3 libavc1394-0 libboost-iostreams1.71.0
#   libboost-thread1.71.0 libbrlapi0.7 libcaca0 libcacard0 libcdparanoia0
#   libcolord2 libcups2 libdrm-common libdrm2 libdv4 libepoxy0 libfdt1 libflac8
#   libgbm1 libgstreamer-plugins-base1.0-0 libgstreamer-plugins-good1.0-0
#   libgtk-3-0 libgtk-3-bin libgtk-3-common libgudev-1.0-0 libibverbs1
#   libiec61883-0 libiscsi7 libjack-jackd2-0 libjson-glib-1.0-0
#   libjson-glib-1.0-common libmp3lame0 libmpg123-0 libnl-3-200
#   libnl-route-3-200 libnspr4 libnss3 libnuma1 libopus0 liborc-0.4-0
#   libpcsclite1 libpmem1 libpulse0 libqrencode4 librados2 libraw1394-11 librbd1
#   librdmacm1 librest-0.7-0 libsamplerate0 libshout3 libslang2 libslirp0
#   libsndfile1 libsoup-gnome2.4-1 libspeex1 libspice-server1 libtag1v5
#   libtag1v5-vanilla libtheora0 libtwolame0 libusb-1.0-0 libusbredirparser1
#   libv4l-0 libv4lconvert0 libvirglrenderer1 libvisual-0.4-0 libvorbisenc2
#   libvpx6 libvte-2.91-0 libvte-2.91-common libwavpack1 libwayland-client0
#   libwayland-cursor0 libwayland-egl1 libwayland-server0 libwrap0 libx11-xcb1
#   libxcomposite1 libxcursor1 libxdamage1 libxfixes3 libxi6 libxinerama1
#   libxkbcommon0 libxmu6 libxmuu1 libxrandr2 libxtst6 libxv1 msr-tools ovmf
#   pass qemu-block-extra qemu-system-common qemu-system-data qemu-system-gui
#   qemu-system-x86 qemu-utils qrencode seabios sharutils tree ubuntu-mono xauth
#   xclip xkb-data
# Suggested packages:
#   gvfs colord cups-common libdv-bin oss-compat libvisual-0.4-plugins jackd2
#   opus-tools pcscd pulseaudio libraw1394-doc speex gstreamer1.0-plugins-ugly
#   python libxml-simple-perl ruby samba vde2 debootstrap sharutils-doc
#   bsd-mailx | mailx
# The following NEW packages will be installed:
#   acl adwaita-icon-theme at-spi2-core cpu-checker desktop-file-utils
#   docker-ce-cli docker-scan-plugin gstreamer1.0-plugins-base
#   gstreamer1.0-plugins-good gstreamer1.0-x gtk-update-icon-cache
#   humanity-icon-theme ibverbs-providers ipxe-qemu
#   ipxe-qemu-256k-compat-efi-roms libaa1 libaio1 libasyncns0 libatk-bridge2.0-0
#   libatk1.0-0 libatk1.0-data libatspi2.0-0 libavahi-client3
#   libavahi-common-data libavahi-common3 libavc1394-0 libboost-iostreams1.71.0
#   libboost-thread1.71.0 libbrlapi0.7 libcaca0 libcacard0 libcdparanoia0
#   libcolord2 libcups2 libdrm-common libdrm2 libdv4 libepoxy0 libfdt1 libflac8
#   libgbm1 libgstreamer-plugins-base1.0-0 libgstreamer-plugins-good1.0-0
#   libgtk-3-0 libgtk-3-bin libgtk-3-common libgudev-1.0-0 libibverbs1
#   libiec61883-0 libiscsi7 libjack-jackd2-0 libjson-glib-1.0-0
#   libjson-glib-1.0-common libmp3lame0 libmpg123-0 libnl-3-200
#   libnl-route-3-200 libnspr4 libnss3 libnuma1 libopus0 liborc-0.4-0
#   libpcsclite1 libpmem1 libpulse0 libqrencode4 librados2 libraw1394-11 librbd1
#   librdmacm1 librest-0.7-0 libsamplerate0 libshout3 libslang2 libslirp0
#   libsndfile1 libsoup-gnome2.4-1 libspeex1 libspice-server1 libtag1v5
#   libtag1v5-vanilla libtheora0 libtwolame0 libusb-1.0-0 libusbredirparser1
#   libv4l-0 libv4lconvert0 libvirglrenderer1 libvisual-0.4-0 libvorbisenc2
#   libvpx6 libvte-2.91-0 libvte-2.91-common libwavpack1 libwayland-client0
#   libwayland-cursor0 libwayland-egl1 libwayland-server0 libwrap0 libx11-xcb1
#   libxcomposite1 libxcursor1 libxdamage1 libxfixes3 libxi6 libxinerama1
#   libxkbcommon0 libxmu6 libxmuu1 libxrandr2 libxtst6 libxv1 msr-tools ovmf
#   pass qemu-block-extra qemu-system-common qemu-system-data qemu-system-gui
#   qemu-system-x86 qemu-utils qrencode seabios sharutils tree ubuntu-mono xauth
#   xclip xkb-data
# 0 upgraded, 129 newly installed, 0 to remove and 25 not upgraded.
# 1 not fully installed or removed.
# Need to get 84.2 MB of archives.
# After this operation, 350 MB of additional disk space will be used.
# Do you want to continue? [Y/n] ^C

# %%
# !sudo apt-get install docker-ce-cli
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# You might want to run 'apt --fix-broken install' to correct these.
# The following packages have unmet dependencies:
#  docker-desktop : Depends: qemu-system-x86 (>= 5.2.0) but it is not going to be installed
#                   Depends: pass but it is not going to be installed
#                   Depends: desktop-file-utils but it is not going to be installed
#                   Depends: libgtk-3-0 but it is not going to be installed
#                   Depends: libx11-xcb1 but it is not going to be installed
# E: Unmet dependencies. Try 'apt --fix-broken install' with no packages (or specify a solution).

# %%
cat /etc/os-release
# Out:
# NAME="Ubuntu"
# VERSION="20.04.4 LTS (Focal Fossa)"
# ID=ubuntu
# ID_LIKE=debian
# PRETTY_NAME="Ubuntu 20.04.4 LTS"
# VERSION_ID="20.04"
# HOME_URL="https://www.ubuntu.com/"
# SUPPORT_URL="https://help.ubuntu.com/"
# BUG_REPORT_URL="https://bugs.launchpad.net/ubuntu/"
# PRIVACY_POLICY_URL="https://www.ubuntu.com/legal/terms-and-policies/privacy-policy"
# VERSION_CODENAME=focal
# UBUNTU_CODENAME=focal

# %%
# !sudo apt-get remove docker docker-engine docker.io containerd runc
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Package 'docker-engine' is not installed, so not removed
# Package 'docker' is not installed, so not removed
# Package 'containerd' is not installed, so not removed
# Package 'runc' is not installed, so not removed
# Package 'docker.io' is not installed, so not removed
# 0 upgraded, 0 newly installed, 0 to remove and 25 not upgraded.

# %%
# !sudo apt-get update
# !sudo apt-get install \
    ca-certificates \
    curl \
    gnupg \
    lsb-release
# Out:
# Hit:2 https://download.docker.com/linux/ubuntu focal InRelease
# Hit:3 http://ppa.launchpad.net/git-core/ppa/ubuntu focal InRelease
# Hit:4 http://ppa.launchpad.net/ondrej/apache2/ubuntu focal InRelease
# Hit:1 https://apt.llvm.org/focal llvm-toolchain-focal InRelease
# Hit:5 http://ppa.launchpad.net/ondrej/nginx-mainline/ubuntu focal InRelease
# Hit:6 http://ppa.launchpad.net/ondrej/php/ubuntu focal InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu focal InRelease
# Hit:8 http://security.ubuntu.com/ubuntu focal-security InRelease
# Get:9 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal-backports InRelease [108 kB]
# Fetched 222 kB in 1s (299 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# lsb-release is already the newest version (11.1.0ubuntu2).
# lsb-release set to manually installed.
# ca-certificates is already the newest version (20210119~20.04.2).
# curl is already the newest version (7.68.0-1ubuntu2.11).
# gnupg is already the newest version (2.2.19-3ubuntu2.1).
# 0 upgraded, 0 newly installed, 0 to remove and 25 not upgraded.

# %%
# !sudo mkdir -p /etc/apt/keyrings

# %%
# !curl -fsSL https://download.docker.com/linux/ubuntu/gpg | sudo gpg --dearmor -o /etc/apt/keyrings/docker.gpg

# %%
# !echo \
  "deb [arch=$(dpkg --print-architecture) signed-by=/etc/apt/keyrings/docker.gpg] https://download.docker.com/linux/ubuntu \
  $(lsb_release -cs) stable" | sudo tee /etc/apt/sources.list.d/docker.list > /dev/null

# %%
! sudo apt-get update
# Out:
# Hit:2 http://ppa.launchpad.net/git-core/ppa/ubuntu focal InRelease
# Hit:3 https://download.docker.com/linux/ubuntu focal InRelease
# Hit:4 http://ppa.launchpad.net/ondrej/apache2/ubuntu focal InRelease
# Hit:5 http://ppa.launchpad.net/ondrej/nginx-mainline/ubuntu focal InRelease
# Hit:1 https://apt.llvm.org/focal llvm-toolchain-focal InRelease
# Hit:6 http://ppa.launchpad.net/ondrej/php/ubuntu focal InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu focal InRelease
# Hit:8 http://security.ubuntu.com/ubuntu focal-security InRelease
# Get:9 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal-backports InRelease [108 kB]
# Fetched 222 kB in 1s (267 kB/s)
# Reading package lists... Done

# %%
# !sudo apt-get install docker-ce docker-ce-cli containerd.io docker-compose-plugin
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# docker-ce-cli is already the newest version (5:20.10.16~3-0~ubuntu-focal).
# docker-ce-cli set to manually installed.
# The following additional packages will be installed:
#   apparmor docker-ce-rootless-extras pigz slirp4netns
# Suggested packages:
#   apparmor-profiles-extra apparmor-utils aufs-tools cgroupfs-mount
#   | cgroup-lite
# The following NEW packages will be installed:
#   apparmor containerd.io docker-ce docker-ce-rootless-extras
#   docker-compose-plugin pigz slirp4netns
# 0 upgraded, 7 newly installed, 0 to remove and 25 not upgraded.
# Need to get 64.5 MB of archives.
# After this operation, 277 MB of additional disk space will be used.
# Do you want to continue? [Y/n] ^C

# %%
# !apt-cache madison docker-ce
# Out:
#  docker-ce | 5:20.10.16~3-0~ubuntu-focal | https://download.docker.com/linux/ubuntu focal/stable amd64 Packages
#  docker-ce | 5:20.10.15~3-0~ubuntu-focal | https://download.docker.com/linux/ubuntu focal/stable amd64 Packages
#  docker-ce | 5:20.10.14~3-0~ubuntu-focal | https://download.docker.com/linux/ubuntu focal/stable amd64 Packages
#  docker-ce | 5:20.10.13~3-0~ubuntu-focal | https://download.docker.com/linux/ubuntu focal/stable amd64 Packages
#  docker-ce | 5:20.10.12~3-0~ubuntu-focal | https://download.docker.com/linux/ubuntu focal/stable amd64 Packages
#  docker-ce | 5:20.10.11~3-0~ubuntu-focal | https://download.docker.com/linux/ubuntu focal/stable amd64 Packages
#  docker-ce | 5:20.10.10~3-0~ubuntu-focal | https://download.docker.com/linux/ubuntu focal/stable amd64 Packages
#  docker-ce | 5:20.10.9~3-0~ubuntu-focal | https://download.docker.com/linux/ubuntu focal/stable amd64 Packages
#  docker-ce | 5:20.10.8~3-0~ubuntu-focal | https://download.docker.com/linux/ubuntu focal/stable amd64 Packages
#  docker-ce | 5:20.10.7~3-0~ubuntu-focal | https://download.docker.com/linux/ubuntu focal/stable amd64 Packages
#  docker-ce | 5:20.10.6~3-0~ubuntu-focal | https://download.docker.com/linux/ubuntu focal/stable amd64 Packages
#  docker-ce | 5:20.10.5~3-0~ubuntu-focal | https://download.docker.com/linux/ubuntu focal/stable amd64 Packages
#  docker-ce | 5:20.10.4~3-0~ubuntu-focal | https://download.docker.com/linux/ubuntu focal/stable amd64 Packages
#  docker-ce | 5:20.10.3~3-0~ubuntu-focal | https://download.docker.com/linux/ubuntu focal/stable amd64 Packages
#  docker-ce | 5:20.10.2~3-0~ubuntu-focal | https://download.docker.com/linux/ubuntu focal/stable amd64 Packages
#  docker-ce | 5:20.10.1~3-0~ubuntu-focal | https://download.docker.com/linux/ubuntu focal/stable amd64 Packages
#  docker-ce | 5:20.10.0~3-0~ubuntu-focal | https://download.docker.com/linux/ubuntu focal/stable amd64 Packages
#  docker-ce | 5:19.03.15~3-0~ubuntu-focal | https://download.docker.com/linux/ubuntu focal/stable amd64 Packages
#  docker-ce | 5:19.03.14~3-0~ubuntu-focal | https://download.docker.com/linux/ubuntu focal/stable amd64 Packages
#  docker-ce | 5:19.03.13~3-0~ubuntu-focal | https://download.docker.com/linux/ubuntu focal/stable amd64 Packages
#  docker-ce | 5:19.03.12~3-0~ubuntu-focal | https://download.docker.com/linux/ubuntu focal/stable amd64 Packages
#  docker-ce | 5:19.03.11~3-0~ubuntu-focal | https://download.docker.com/linux/ubuntu focal/stable amd64 Packages
#  docker-ce | 5:19.03.10~3-0~ubuntu-focal | https://download.docker.com/linux/ubuntu focal/stable amd64 Packages
#  docker-ce | 5:19.03.9~3-0~ubuntu-focal | https://download.docker.com/linux/ubuntu focal/stable amd64 Packages

# %%
# !sudo apt-get install docker-ce="5:20.10.16~3-0~ubuntu-focal"  docker-ce-cli="5:20.10.16~3-0~ubuntu-focal" containerd.io docker-compose-plugin
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# containerd.io is already the newest version (1.6.4-1).
# docker-ce-cli is already the newest version (5:20.10.16~3-0~ubuntu-focal).
# docker-ce is already the newest version (5:20.10.16~3-0~ubuntu-focal).
# docker-compose-plugin is already the newest version (2.5.0~ubuntu-focal).
# 0 upgraded, 0 newly installed, 0 to remove and 25 not upgraded.

# %%
# !sudo docker run hello-world
# Out:
# Unable to find image 'hello-world:latest' locally
# latest: Pulling from library/hello-world
#
# 9710123e: Pull complete 479kB/2.479kBBDigest: sha256:80f31da1ac7b312ba29d65080fddf797dd76acfb870e677f390d5acba9741b17
# Status: Downloaded newer image for hello-world:latest
#
# Hello from Docker!
# This message shows that your installation appears to be working correctly.
#
# To generate this message, Docker took the following steps:
#  1. The Docker client contacted the Docker daemon.
#  2. The Docker daemon pulled the "hello-world" image from the Docker Hub.
#     (amd64)
#  3. The Docker daemon created a new container from that image which runs the
#     executable that produces the output you are currently reading.
#  4. The Docker daemon streamed that output to the Docker client, which sent it
#     to your terminal.
#
# To try something more ambitious, you can run an Ubuntu container with:
#  $ docker run -it ubuntu bash
#
# Share images, automate workflows, and more with a free Docker ID:
#  https://hub.docker.com/
#
# For more examples and ideas, visit:
#  https://docs.docker.com/get-started/

# %%
# !docker run -it ubuntu bash
# Out:
# Unable to find image 'ubuntu:latest' locally
# latest: Pulling from library/ubuntu
#
# Digest: sha256:26c68657ccce2cb0a31b330cb0be2b5e108d467f641c62e13ab40cbec258c68d[1A
# Status: Downloaded newer image for ubuntu:latest
# oot@fa7d74ee3a69: /root@fa7d74ee3a69:/# 9:/# ^C
#
# root@fa7d74ee3a69:/#

# %%
# !sudo docker run hello-world
# Out:
# Hello from Docker!
# This message shows that your installation appears to be working correctly.
#
# To generate this message, Docker took the following steps:
#  1. The Docker client contacted the Docker daemon.
#  2. The Docker daemon pulled the "hello-world" image from the Docker Hub.
#     (amd64)
#  3. The Docker daemon created a new container from that image which runs the
#     executable that produces the output you are currently reading.
#  4. The Docker daemon streamed that output to the Docker client, which sent it
#     to your terminal.
#
# To try something more ambitious, you can run an Ubuntu container with:
#  $ docker run -it ubuntu bash
#
# Share images, automate workflows, and more with a free Docker ID:
#  https://hub.docker.com/
#
# For more examples and ideas, visit:
#  https://docs.docker.com/get-started/

# %%
# !pwd
# Out:
# /workspace/AirflowDAG

# %%
# !docker-compose up -d
# Out:
# no configuration file provided: not found

# %%
# !cd airflow-tutorial/

# %%
# !pwd
# Out:
# /workspace/AirflowDAG

# %% [markdown]
# # new file

# %%
# !mkdir airflow-docker
# !cd airflow-docker

# %%
# !pwd
# Out:
# /workspace/AirflowDAG

# %%
curl -LfO "https://airflow.apache.org/docs/apache-airflow/stable/docker-compose.yaml"

# %%
# !mkdir ./dags ./plugins ./logs

# %%
# !docker exec <number> airflow version

# %%
# !echo -e "AIRFLOW_UID=$(id -u)\nAIRFLOW_GID=0" > .env

# %%
# !docker-compose up airflow-init

# %%
# !docker-compose up

# %%
# !curl -X GET --user "airflow:airflow" "http://localhost:8080/api/v1/dags"
# Out:
# {
#   "dags": [
#     {
#       "dag_id": "example_bash_operator",
#       "default_view": "grid",
#       "description": null,
#       "file_token": ".eJw9yjEOgCAMAMC_sEsHB59DClYgFttQEuX3boyXnIMijQBrv1he8CwJGbhG0DmKPLs_wOqgTTHdmMlWpQ-bMoUTsy1EtBJEqeOQ7nW6H6aeI_0.Ec2Fk5TlubQ7KfzRV6UTcT-YF3E",
#       "fileloc": "/home/airflow/.local/lib/python3.7/site-packages/airflow/example_dags/example_bash_operator.py",
#       "has_import_errors": false,
#       "has_task_concurrency_limits": false,
#       "is_active": true,
#       "is_paused": true,
#       "is_subdag": false,
#       "last_expired": null,
#       "last_parsed_time": "2022-05-28T01:24:25.940132+00:00",
#       "last_pickled": null,
#       "max_active_runs": 16,
#       "max_active_tasks": 16,
#       "next_dagrun": "2022-05-27T00:00:00+00:00",
#       "next_dagrun_create_after": "2022-05-28T00:00:00+00:00",
#       "next_dagrun_data_interval_end": "2022-05-28T00:00:00+00:00",
#       "next_dagrun_data_interval_start": "2022-05-27T00:00:00+00:00",
#       "owners": [
#         "airflow"
#       ],
#       "pickle_id": null,
#       "root_dag_id": null,
#       "schedule_interval": {
#         "__type": "CronExpression",
#         "value": "0 0 * * *"
#       },
#       "scheduler_lock": null,
#       "tags": [
#         {
#           "name": "example2"
#         },
#         {
#           "name": "example"
#         }
#       ],
#       "timetable_description": "At 00:00"
#     },
#     {
#       "dag_id": "example_branch_datetime_operator_2",
#       "default_view": "grid",
#       "description": null,
#       "file_token": ".eJw9yjEOgCAMQNG7sEsHB49DClYhFtpAE-X2Ojn-l-8gSyXA0g-WGzxLQgYuEXRalrb6DUYxWhTThSeNf6UHqzKFHc_xR-zYUv7MyEqlIEodTbrX6V5QcSh5.ft330CVKnAkA0IXevMwU6EXGrAw",
#       "fileloc": "/home/airflow/.local/lib/python3.7/site-packages/airflow/example_dags/example_branch_datetime_operator.py",
#       "has_import_errors": false,
#       "has_task_concurrency_limits": false,
#       "is_active": true,
#       "is_paused": true,
#       "is_subdag": false,
#       "last_expired": null,
#       "last_parsed_time": "2022-05-28T01:24:25.941614+00:00",
#       "last_pickled": null,
#       "max_active_runs": 16,
#       "max_active_tasks": 16,
#       "next_dagrun": "2022-05-27T00:00:00+00:00",
#       "next_dagrun_create_after": "2022-05-28T00:00:00+00:00",
#       "next_dagrun_data_interval_end": "2022-05-28T00:00:00+00:00",
#       "next_dagrun_data_interval_start": "2022-05-27T00:00:00+00:00",
#       "owners": [
#         "airflow"
#       ],
#       "pickle_id": null,
#       "root_dag_id": null,
#       "schedule_interval": {
#         "__type": "CronExpression",
#         "value": "@daily"
#       },
#       "scheduler_lock": null,
#       "tags": [
#         {
#           "name": "example"
#         }
#       ],
#       "timetable_description": "At 00:00"
#     },
#     {
#       "dag_id": "example_branch_dop_operator_v3",
#       "default_view": "grid",
#       "description": null,
#       "file_token": ".eJw9yzEOgCAMQNG7sEsHB4_TVKxALLYBEuX2DiaMP3nfQdLCQLmeog940UACknew0ZPeq9-g5c6LUbgocpuUXyomjAfFNmOvdIeE_4uHGqpxpa4VV2_DffoAKgI.stYZJYxWASLzWkUEjmaaUWT6cnc",
#       "fileloc": "/home/airflow/.local/lib/python3.7/site-packages/airflow/example_dags/example_branch_python_dop_operator_3.py",
#       "has_import_errors": false,
#       "has_task_concurrency_limits": false,
#       "is_active": true,
#       "is_paused": true,
#       "is_subdag": false,
#       "last_expired": null,
#       "last_parsed_time": "2022-05-28T01:24:26.137748+00:00",
#       "last_pickled": null,
#       "max_active_runs": 16,
#       "max_active_tasks": 16,
#       "next_dagrun": "2022-05-28T01:23:00+00:00",
#       "next_dagrun_create_after": "2022-05-28T01:24:00+00:00",
#       "next_dagrun_data_interval_end": "2022-05-28T01:24:00+00:00",
#       "next_dagrun_data_interval_start": "2022-05-28T01:23:00+00:00",
#       "owners": [
#         "airflow"
#       ],
#       "pickle_id": null,
#       "root_dag_id": null,
#       "schedule_interval": {
#         "__type": "CronExpression",
#         "value": "*/1 * * * *"
#       },
#       "scheduler_lock": null,
#       "tags": [
#         {
#           "name": "example"
#         }
#       ],
#       "timetable_description": "Every minute"
#     },
#     {
#       "dag_id": "example_branch_labels",
#       "default_view": "grid",
#       "description": null,
#       "file_token": ".eJw9yjEOgCAMAMC_sEsHB59DClYgFtpQEuX3bo6XnIMijQDruFge8CwJGbhG0DWL9N0fYHXSpphuzGR_pRebMoUTs_2IA3sqgTESm9flPqVYI9Q.VX26UMuLhIeiOU2LUAA4OZJQ2Hw",
#       "fileloc": "/home/airflow/.local/lib/python3.7/site-packages/airflow/example_dags/example_branch_labels.py",
#       "has_import_errors": false,
#       "has_task_concurrency_limits": false,
#       "is_active": true,
#       "is_paused": true,
#       "is_subdag": false,
#       "last_expired": null,
#       "last_parsed_time": "2022-05-28T01:24:26.070725+00:00",
#       "last_pickled": null,
#       "max_active_runs": 16,
#       "max_active_tasks": 16,
#       "next_dagrun": "2022-05-27T00:00:00+00:00",
#       "next_dagrun_create_after": "2022-05-28T00:00:00+00:00",
#       "next_dagrun_data_interval_end": "2022-05-28T00:00:00+00:00",
#       "next_dagrun_data_interval_start": "2022-05-27T00:00:00+00:00",
#       "owners": [
#         "airflow"
#       ],
#       "pickle_id": null,
#       "root_dag_id": null,
#       "schedule_interval": {
#         "__type": "CronExpression",
#         "value": "@daily"
#       },
#       "scheduler_lock": null,
#       "tags": [],
#       "timetable_description": "At 00:00"
#     },
#     {
#       "dag_id": "example_branch_operator",
#       "default_view": "grid",
#       "description": null,
#       "file_token": ".eJw9yjEOgCAMAMC_sEsHB59DClYgFtoUEuX3bo6XnIMijQCrXSwPeJaEDFwj6JpF-u4PGHXSpphuzDT-Si82ZQon5vEjGvZUgigZTjGvy33wbSTN.wPXmBHdvJ0asfA6Z8u73QVMtcas",
#       "fileloc": "/home/airflow/.local/lib/python3.7/site-packages/airflow/example_dags/example_branch_operator.py",
#       "has_import_errors": false,
#       "has_task_concurrency_limits": false,
#       "is_active": true,
#       "is_paused": true,
#       "is_subdag": false,
#       "last_expired": null,
#       "last_parsed_time": "2022-05-28T01:24:26.074089+00:00",
#       "last_pickled": null,
#       "max_active_runs": 16,
#       "max_active_tasks": 16,
#       "next_dagrun": "2022-05-27T00:00:00+00:00",
#       "next_dagrun_create_after": "2022-05-28T00:00:00+00:00",
#       "next_dagrun_data_interval_end": "2022-05-28T00:00:00+00:00",
#       "next_dagrun_data_interval_start": "2022-05-27T00:00:00+00:00",
#       "owners": [
#         "airflow"
#       ],
#       "pickle_id": null,
#       "root_dag_id": null,
#       "schedule_interval": {
#         "__type": "CronExpression",
#         "value": "@daily"
#       },
#       "scheduler_lock": null,
#       "tags": [
#         {
#           "name": "example2"
#         },
#         {
#           "name": "example"
#         }
#       ],
#       "timetable_description": "At 00:00"
#     },
#     {
#       "dag_id": "example_branch_python_operator_decorator",
#       "default_view": "grid",
#       "description": null,
#       "file_token": ".eJw9yjEOgCAMQNG7uEsHB49DClQgFtoAiXJ7Ewe2_5K_QZJCgLldLA8YFo8MnB3oHEnqYU7oedCu6G-M1NdKLxZlsgFjX3ANq09WlBoOaTaQl7-Mzu0DevYo7w.1wDRhf0uZcWeVCusZbsvCdlmjqo",
#       "fileloc": "/home/airflow/.local/lib/python3.7/site-packages/airflow/example_dags/example_branch_operator_decorator.py",
#       "has_import_errors": false,
#       "has_task_concurrency_limits": false,
#       "is_active": true,
#       "is_paused": true,
#       "is_subdag": false,
#       "last_expired": null,
#       "last_parsed_time": "2022-05-28T01:24:26.140386+00:00",
#       "last_pickled": null,
#       "max_active_runs": 16,
#       "max_active_tasks": 16,
#       "next_dagrun": "2022-05-27T00:00:00+00:00",
#       "next_dagrun_create_after": "2022-05-28T00:00:00+00:00",
#       "next_dagrun_data_interval_end": "2022-05-28T00:00:00+00:00",
#       "next_dagrun_data_interval_start": "2022-05-27T00:00:00+00:00",
#       "owners": [
#         "airflow"
#       ],
#       "pickle_id": null,
#       "root_dag_id": null,
#       "schedule_interval": {
#         "__type": "CronExpression",
#         "value": "@daily"
#       },
#       "scheduler_lock": null,
#       "tags": [
#         {
#           "name": "example2"
#         },
#         {
#           "name": "example"
#         }
#       ],
#       "timetable_description": "At 00:00"
#     },
#     {
#       "dag_id": "example_complex",
#       "default_view": "grid",
#       "description": null,
#       "file_token": ".eJxT0s_Iz03VT8wsSsvJL9fXy8lPTszRz8lM0i-oLMnIzzPWM9cvzixJ1S1ITM5OTE8thitNrUjMLchJjU9JTC-Gc5LzQVSFXkGlEgDTMSGM.nrRn6exJVhIxBBDcHrhvzeuNqy8",
#       "fileloc": "/home/airflow/.local/lib/python3.7/site-packages/airflow/example_dags/example_complex.py",
#       "has_import_errors": false,
#       "has_task_concurrency_limits": false,
#       "is_active": true,
#       "is_paused": true,
#       "is_subdag": false,
#       "last_expired": null,
#       "last_parsed_time": "2022-05-28T01:24:26.212142+00:00",
#       "last_pickled": null,
#       "max_active_runs": 16,
#       "max_active_tasks": 16,
#       "next_dagrun": null,
#       "next_dagrun_create_after": null,
#       "next_dagrun_data_interval_end": null,
#       "next_dagrun_data_interval_start": null,
#       "owners": [
#         "airflow"
#       ],
#       "pickle_id": null,
#       "root_dag_id": null,
#       "schedule_interval": null,
#       "scheduler_lock": null,
#       "tags": [
#         {
#           "name": "example2"
#         },
#         {
#           "name": "example"
#         },
#         {
#           "name": "example3"
#         }
#       ],
#       "timetable_description": "Never, external triggers only"
#     },
#     {
#       "dag_id": "example_dag_decorator",
#       "default_view": "grid",
#       "description": null,
#       "file_token": ".eJxNyjEOgCAMAMC_sEsHB59DKlRoLLYBEuX3bsbxknNQtBIgt0P0Bi8aUUB4B5uj6LX6DToPWgzjiZn6V-nBakIhYe5_hERRGw5t3qZ7AaUsI-I.L_P_nAGIOglwLm5bK36QyVbNOIY",
#       "fileloc": "/home/airflow/.local/lib/python3.7/site-packages/airflow/example_dags/example_dag_decorator.py",
#       "has_import_errors": false,
#       "has_task_concurrency_limits": false,
#       "is_active": true,
#       "is_paused": true,
#       "is_subdag": false,
#       "last_expired": null,
#       "last_parsed_time": "2022-05-28T01:24:27.436153+00:00",
#       "last_pickled": null,
#       "max_active_runs": 16,
#       "max_active_tasks": 16,
#       "next_dagrun": null,
#       "next_dagrun_create_after": null,
#       "next_dagrun_data_interval_end": null,
#       "next_dagrun_data_interval_start": null,
#       "owners": [
#         "airflow"
#       ],
#       "pickle_id": null,
#       "root_dag_id": null,
#       "schedule_interval": null,
#       "scheduler_lock": null,
#       "tags": [
#         {
#           "name": "example"
#         }
#       ],
#       "timetable_description": "Never, external triggers only"
#     },
#     {
#       "dag_id": "example_external_task_marker_child",
#       "default_view": "grid",
#       "description": null,
#       "file_token": ".eJw9yjsOgCAQBcC72MsWFh6HPHEFwvIJkAi3NzaUk8xGLkcm-PpIfklJNhASf1GZ3eV0qJOa77wXmADLbVUeiEVY37BtgUfnmiC6owUdUQPXf6gytw9Tcyh1.m8Rz6AYfh1Fxo8nDJ2tVIGR7-NM",
#       "fileloc": "/home/airflow/.local/lib/python3.7/site-packages/airflow/example_dags/example_external_task_marker_dag.py",
#       "has_import_errors": false,
#       "has_task_concurrency_limits": false,
#       "is_active": true,
#       "is_paused": true,
#       "is_subdag": false,
#       "last_expired": null,
#       "last_parsed_time": "2022-05-28T01:24:26.289891+00:00",
#       "last_pickled": null,
#       "max_active_runs": 16,
#       "max_active_tasks": 16,
#       "next_dagrun": null,
#       "next_dagrun_create_after": null,
#       "next_dagrun_data_interval_end": null,
#       "next_dagrun_data_interval_start": null,
#       "owners": [
#         "airflow"
#       ],
#       "pickle_id": null,
#       "root_dag_id": null,
#       "schedule_interval": null,
#       "scheduler_lock": null,
#       "tags": [
#         {
#           "name": "example2"
#         }
#       ],
#       "timetable_description": "Never, external triggers only"
#     },
#     {
#       "dag_id": "example_external_task_marker_parent",
#       "default_view": "grid",
#       "description": null,
#       "file_token": ".eJw9yjsOgCAQBcC72MsWFh6HPHEFwvIJkAi3NzaUk8xGLkcm-PpIfklJNhASf1GZ3eV0qJOa77wXmADLbVUeiEVY37BtgUfnmiC6owUdUQPXf6gytw9Tcyh1.m8Rz6AYfh1Fxo8nDJ2tVIGR7-NM",
#       "fileloc": "/home/airflow/.local/lib/python3.7/site-packages/airflow/example_dags/example_external_task_marker_dag.py",
#       "has_import_errors": false,
#       "has_task_concurrency_limits": false,
#       "is_active": true,
#       "is_paused": true,
#       "is_subdag": false,
#       "last_expired": null,
#       "last_parsed_time": "2022-05-28T01:24:26.290191+00:00",
#       "last_pickled": null,
#       "max_active_runs": 16,
#       "max_active_tasks": 16,
#       "next_dagrun": null,
#       "next_dagrun_create_after": null,
#       "next_dagrun_data_interval_end": null,
#       "next_dagrun_data_interval_start": null,
#       "owners": [
#         "airflow"
#       ],
#       "pickle_id": null,
#       "root_dag_id": null,
#       "schedule_interval": null,
#       "scheduler_lock": null,
#       "tags": [
#         {
#           "name": "example2"
#         }
#       ],
#       "timetable_description": "Never, external triggers only"
#     },
#     {
#       "dag_id": "example_kubernetes_executor",
#       "default_view": "grid",
#       "description": null,
#       "file_token": ".eJw9yjEOgCAMBdC7uEsHB49DKn6BUCkBjHJ7N8aXvIWC3iCO9RJ9yYg6FpJ4UBk9aN7MTi12rIVdYo82Kz6-i8Ce7NtEeg7UjI5m8cE9XaspY_kBi74mmg.rd8vfx0L8fVwDLaoQJpbWph1rcg",
#       "fileloc": "/home/airflow/.local/lib/python3.7/site-packages/airflow/example_dags/example_kubernetes_executor.py",
#       "has_import_errors": false,
#       "has_task_concurrency_limits": false,
#       "is_active": true,
#       "is_paused": true,
#       "is_subdag": false,
#       "last_expired": null,
#       "last_parsed_time": "2022-05-28T01:24:27.297397+00:00",
#       "last_pickled": null,
#       "max_active_runs": 16,
#       "max_active_tasks": 16,
#       "next_dagrun": null,
#       "next_dagrun_create_after": null,
#       "next_dagrun_data_interval_end": null,
#       "next_dagrun_data_interval_start": null,
#       "owners": [
#         "airflow"
#       ],
#       "pickle_id": null,
#       "root_dag_id": null,
#       "schedule_interval": null,
#       "scheduler_lock": null,
#       "tags": [
#         {
#           "name": "example3"
#         }
#       ],
#       "timetable_description": "Never, external triggers only"
#     },
#     {
#       "dag_id": "example_local_kubernetes_executor",
#       "default_view": "grid",
#       "description": null,
#       "file_token": ".eJw9yzEOgCAQBdG70MsWFh6HrPgF4uoSwIi3N7GgnOSNoagniFPZRR-yop6FJK2U3xb1mu1CNTVMmf3BAXVQdD6zwG0c6oh_d8e9olxoqA4d_m5abH7NB3wOKQQ.nA-qODp9hVlRJ44PGS9ieY8H_K8",
#       "fileloc": "/home/airflow/.local/lib/python3.7/site-packages/airflow/example_dags/example_local_kubernetes_executor.py",
#       "has_import_errors": false,
#       "has_task_concurrency_limits": false,
#       "is_active": true,
#       "is_paused": true,
#       "is_subdag": false,
#       "last_expired": null,
#       "last_parsed_time": "2022-05-28T01:24:27.539851+00:00",
#       "last_pickled": null,
#       "max_active_runs": 16,
#       "max_active_tasks": 16,
#       "next_dagrun": null,
#       "next_dagrun_create_after": null,
#       "next_dagrun_data_interval_end": null,
#       "next_dagrun_data_interval_start": null,
#       "owners": [
#         "airflow"
#       ],
#       "pickle_id": null,
#       "root_dag_id": null,
#       "schedule_interval": null,
#       "scheduler_lock": null,
#       "tags": [
#         {
#           "name": "example3"
#         }
#       ],
#       "timetable_description": "Never, external triggers only"
#     },
#     {
#       "dag_id": "example_nested_branch_dag",
#       "default_view": "grid",
#       "description": null,
#       "file_token": ".eJw9yjEOgCAMQNG7uEsHB49DClQgFkooiXJ748L48_4GSQoB5n6xPGBYPDJwdtDmSFIPc4LmQXtDf2MkXSu9WBqTDRh1RSUdFKzrWH36ybS5fTtXJW8.mi9JR9SnIdMEVStnxi1Dd4H2eEM",
#       "fileloc": "/home/airflow/.local/lib/python3.7/site-packages/airflow/example_dags/example_nested_branch_dag.py",
#       "has_import_errors": false,
#       "has_task_concurrency_limits": false,
#       "is_active": true,
#       "is_paused": true,
#       "is_subdag": false,
#       "last_expired": null,
#       "last_parsed_time": "2022-05-28T01:24:27.572066+00:00",
#       "last_pickled": null,
#       "max_active_runs": 16,
#       "max_active_tasks": 16,
#       "next_dagrun": "2022-05-27T00:00:00+00:00",
#       "next_dagrun_create_after": "2022-05-28T00:00:00+00:00",
#       "next_dagrun_data_interval_end": "2022-05-28T00:00:00+00:00",
#       "next_dagrun_data_interval_start": "2022-05-27T00:00:00+00:00",
#       "owners": [
#         "airflow"
#       ],
#       "pickle_id": null,
#       "root_dag_id": null,
#       "schedule_interval": {
#         "__type": "CronExpression",
#         "value": "@daily"
#       },
#       "scheduler_lock": null,
#       "tags": [
#         {
#           "name": "example"
#         }
#       ],
#       "timetable_description": "At 00:00"
#     },
#     {
#       "dag_id": "example_passing_params_via_test_command",
#       "default_view": "grid",
#       "description": null,
#       "file_token": ".eJw9yjEOwjAMRuG7dCceGDhO9JOa1KodW3UE9PYwdXr6pLfQ5sYEOV7qHyrqDUoqT4pzbj7u5UEpk2-BtqNzXit_YaFcV_S8EMiU0f89YFnfgjo5Z21uhrGWOJcffb4raA.5rnmS4BRmNpnK0tAvrXe3iDTVwI",
#       "fileloc": "/home/airflow/.local/lib/python3.7/site-packages/airflow/example_dags/example_passing_params_via_test_command.py",
#       "has_import_errors": false,
#       "has_task_concurrency_limits": false,
#       "is_active": true,
#       "is_paused": true,
#       "is_subdag": false,
#       "last_expired": null,
#       "last_parsed_time": "2022-05-28T01:24:27.614373+00:00",
#       "last_pickled": null,
#       "max_active_runs": 16,
#       "max_active_tasks": 16,
#       "next_dagrun": "2022-05-28T01:23:00+00:00",
#       "next_dagrun_create_after": "2022-05-28T01:24:00+00:00",
#       "next_dagrun_data_interval_end": "2022-05-28T01:24:00+00:00",
#       "next_dagrun_data_interval_start": "2022-05-28T01:23:00+00:00",
#       "owners": [
#         "airflow"
#       ],
#       "pickle_id": null,
#       "root_dag_id": null,
#       "schedule_interval": {
#         "__type": "CronExpression",
#         "value": "*/1 * * * *"
#       },
#       "scheduler_lock": null,
#       "tags": [
#         {
#           "name": "example"
#         }
#       ],
#       "timetable_description": "Every minute"
#     },
#     {
#       "dag_id": "example_python_operator",
#       "default_view": "grid",
#       "description": null,
#       "file_token": ".eJw9yzEOgCAMQNG7sEsHB49DKlZoLLYBEuX2DiaMP3nfQdZCgFxP0Qe8aEQB4R1s9Kz36jdo3GkxjBcmapPSi8WEwoGpzfinoEYVu1Zvw33z4CUB.okraYVIm_6Fyhx6xQbNHq-uDKV8",
#       "fileloc": "/home/airflow/.local/lib/python3.7/site-packages/airflow/example_dags/example_python_operator.py",
#       "has_import_errors": false,
#       "has_task_concurrency_limits": false,
#       "is_active": true,
#       "is_paused": true,
#       "is_subdag": false,
#       "last_expired": null,
#       "last_parsed_time": "2022-05-28T01:24:27.649042+00:00",
#       "last_pickled": null,
#       "max_active_runs": 16,
#       "max_active_tasks": 16,
#       "next_dagrun": null,
#       "next_dagrun_create_after": null,
#       "next_dagrun_data_interval_end": null,
#       "next_dagrun_data_interval_start": null,
#       "owners": [
#         "airflow"
#       ],
#       "pickle_id": null,
#       "root_dag_id": null,
#       "schedule_interval": null,
#       "scheduler_lock": null,
#       "tags": [
#         {
#           "name": "example"
#         }
#       ],
#       "timetable_description": "Never, external triggers only"
#     },
#     {
#       "dag_id": "example_short_circuit_operator",
#       "default_view": "grid",
#       "description": null,
#       "file_token": ".eJw9yjEOgDAIAMC_uFsGB5_TYEVLpEIoRv29m-MlN0DVRoDsm-gNSbSggPAC9kbVc0ozdA4aDcuBO_W_0oPNhPKKe__Rq3rkwl4ujqxGjqGe7B0-BBwn4Q.exeoTa2rUzp_WH_WE7X5uBv_ERI",
#       "fileloc": "/home/airflow/.local/lib/python3.7/site-packages/airflow/example_dags/example_short_circuit_operator.py",
#       "has_import_errors": false,
#       "has_task_concurrency_limits": false,
#       "is_active": true,
#       "is_paused": true,
#       "is_subdag": false,
#       "last_expired": null,
#       "last_parsed_time": "2022-05-28T01:24:27.715472+00:00",
#       "last_pickled": null,
#       "max_active_runs": 16,
#       "max_active_tasks": 16,
#       "next_dagrun": "2022-05-27T01:24:27.715601+00:00",
#       "next_dagrun_create_after": "2022-05-28T01:24:27.715601+00:00",
#       "next_dagrun_data_interval_end": "2022-05-28T01:24:27.715601+00:00",
#       "next_dagrun_data_interval_start": "2022-05-27T01:24:27.715601+00:00",
#       "owners": [
#         "airflow"
#       ],
#       "pickle_id": null,
#       "root_dag_id": null,
#       "schedule_interval": {
#         "__type": "TimeDelta",
#         "days": 1,
#         "microseconds": 0,
#         "seconds": 0
#       },
#       "scheduler_lock": null,
#       "tags": [
#         {
#           "name": "example"
#         }
#       ],
#       "timetable_description": ""
#     },
#     {
#       "dag_id": "example_skip_dag",
#       "default_view": "grid",
#       "description": null,
#       "file_token": ".eJw9yjEOgCAMQNG7sEsHB49jKlZoKLaxJMrtjYvjf_kBijYC5OsQvSGKJhQQ3sBGL3rOcQHnTpNhqpjJ_5UebCa07pj9D69sn0Qb4QX0-iHW.MidjJ59vQG9IbIfm5B7fjgRUm5g",
#       "fileloc": "/home/airflow/.local/lib/python3.7/site-packages/airflow/example_dags/example_skip_dag.py",
#       "has_import_errors": false,
#       "has_task_concurrency_limits": false,
#       "is_active": true,
#       "is_paused": true,
#       "is_subdag": false,
#       "last_expired": null,
#       "last_parsed_time": "2022-05-28T01:24:27.779006+00:00",
#       "last_pickled": null,
#       "max_active_runs": 16,
#       "max_active_tasks": 16,
#       "next_dagrun": "2022-05-27T01:24:27.779149+00:00",
#       "next_dagrun_create_after": "2022-05-28T01:24:27.779149+00:00",
#       "next_dagrun_data_interval_end": "2022-05-28T01:24:27.779149+00:00",
#       "next_dagrun_data_interval_start": "2022-05-27T01:24:27.779149+00:00",
#       "owners": [
#         "airflow"
#       ],
#       "pickle_id": null,
#       "root_dag_id": null,
#       "schedule_interval": {
#         "__type": "TimeDelta",
#         "days": 1,
#         "microseconds": 0,
#         "seconds": 0
#       },
#       "scheduler_lock": null,
#       "tags": [
#         {
#           "name": "example"
#         }
#       ],
#       "timetable_description": ""
#     },
#     {
#       "dag_id": "example_sla_dag",
#       "default_view": "grid",
#       "description": null,
#       "file_token": ".eJw9yjEOgCAMQNG7sEsHB49jKlZoLLaxJMrtjQvjf_kBilYC5PsQfSCKJhQQ3sB6K3rNcQHnRpNhOjGTj5VerCa07ph9hAv-EK2HD9IqIV8.0BDgCejtilwaKGrz1cmK9DfnMl8",
#       "fileloc": "/home/airflow/.local/lib/python3.7/site-packages/airflow/example_dags/example_sla_dag.py",
#       "has_import_errors": false,
#       "has_task_concurrency_limits": false,
#       "is_active": true,
#       "is_paused": true,
#       "is_subdag": false,
#       "last_expired": null,
#       "last_parsed_time": "2022-05-28T01:24:27.806711+00:00",
#       "last_pickled": null,
#       "max_active_runs": 16,
#       "max_active_tasks": 16,
#       "next_dagrun": "2022-05-28T01:22:00+00:00",
#       "next_dagrun_create_after": "2022-05-28T01:24:00+00:00",
#       "next_dagrun_data_interval_end": "2022-05-28T01:24:00+00:00",
#       "next_dagrun_data_interval_start": "2022-05-28T01:22:00+00:00",
#       "owners": [
#         "airflow"
#       ],
#       "pickle_id": null,
#       "root_dag_id": null,
#       "schedule_interval": {
#         "__type": "CronExpression",
#         "value": "*/2 * * * *"
#       },
#       "scheduler_lock": null,
#       "tags": [],
#       "timetable_description": "Every 2 minutes"
#     },
#     {
#       "dag_id": "example_subdag_operator",
#       "default_view": "grid",
#       "description": null,
#       "file_token": ".eJw9yjEOgCAMAMC_sEsHB59DClYgFtsARvm9ToyXnIEkhQBzPVgesCwBGTh70NGTXKvdoOVOi2I4MVKblV4syuR2jG2i3f63E6WKXarVYT7xKyTV.KtAJ5ntNPI3K8KFTXKHcGktxt_A",
#       "fileloc": "/home/airflow/.local/lib/python3.7/site-packages/airflow/example_dags/example_subdag_operator.py",
#       "has_import_errors": false,
#       "has_task_concurrency_limits": false,
#       "is_active": true,
#       "is_paused": true,
#       "is_subdag": false,
#       "last_expired": null,
#       "last_parsed_time": "2022-05-28T01:24:27.867878+00:00",
#       "last_pickled": null,
#       "max_active_runs": 16,
#       "max_active_tasks": 16,
#       "next_dagrun": "2022-05-26T00:00:00+00:00",
#       "next_dagrun_create_after": "2022-05-26T00:00:00+00:00",
#       "next_dagrun_data_interval_end": "2022-05-26T00:00:00+00:00",
#       "next_dagrun_data_interval_start": "2022-05-26T00:00:00+00:00",
#       "owners": [
#         "airflow"
#       ],
#       "pickle_id": null,
#       "root_dag_id": null,
#       "schedule_interval": {
#         "__type": "CronExpression",
#         "value": "@once"
#       },
#       "scheduler_lock": null,
#       "tags": [
#         {
#           "name": "example"
#         }
#       ],
#       "timetable_description": "Once, as soon as possible"
#     },
#     {
#       "dag_id": "example_task_group",
#       "default_view": "grid",
#       "description": null,
#       "file_token": ".eJw9yjEOgCAMAMC_uEsHB59DKlYgFNtQjPJ7N8ZLboEklQBzu1hecCwBGTgfoKMnuTe3g-VOq2IoGMlmpQ-rMvkTo010tOJjk0edjuUHO9ki0w.rpzudnSvjqTiXzhLuBcMjZZVFzI",
#       "fileloc": "/home/airflow/.local/lib/python3.7/site-packages/airflow/example_dags/example_task_group.py",
#       "has_import_errors": false,
#       "has_task_concurrency_limits": false,
#       "is_active": true,
#       "is_paused": true,
#       "is_subdag": false,
#       "last_expired": null,
#       "last_parsed_time": "2022-05-28T01:24:27.878023+00:00",
#       "last_pickled": null,
#       "max_active_runs": 16,
#       "max_active_tasks": 16,
#       "next_dagrun": "2022-05-27T01:24:27.878160+00:00",
#       "next_dagrun_create_after": "2022-05-28T01:24:27.878160+00:00",
#       "next_dagrun_data_interval_end": "2022-05-28T01:24:27.878160+00:00",
#       "next_dagrun_data_interval_start": "2022-05-27T01:24:27.878160+00:00",
#       "owners": [
#         "airflow"
#       ],
#       "pickle_id": null,
#       "root_dag_id": null,
#       "schedule_interval": {
#         "__type": "TimeDelta",
#         "days": 1,
#         "microseconds": 0,
#         "seconds": 0
#       },
#       "scheduler_lock": null,
#       "tags": [
#         {
#           "name": "example"
#         }
#       ],
#       "timetable_description": ""
#     },
#     {
#       "dag_id": "example_task_group_decorator",
#       "default_view": "grid",
#       "description": null,
#       "file_token": ".eJw9yjEOgCAMAMC_sEsHB59DKlQgFNsARvm9G-MlZyBJJcDcLpYXLItHBs4n6BxJ7t0e0POgTdEXjNRXpQ-rMrmAsS8M7MXFJo-6QF4aDmlWp_kBso8m9Q.dyNH0Gmrj8vBPwTDn11NPrvJiYQ",
#       "fileloc": "/home/airflow/.local/lib/python3.7/site-packages/airflow/example_dags/example_task_group_decorator.py",
#       "has_import_errors": false,
#       "has_task_concurrency_limits": false,
#       "is_active": true,
#       "is_paused": true,
#       "is_subdag": false,
#       "last_expired": null,
#       "last_parsed_time": "2022-05-28T01:24:28.246835+00:00",
#       "last_pickled": null,
#       "max_active_runs": 16,
#       "max_active_tasks": 16,
#       "next_dagrun": "2022-05-27T01:24:28.246937+00:00",
#       "next_dagrun_create_after": "2022-05-28T01:24:28.246937+00:00",
#       "next_dagrun_data_interval_end": "2022-05-28T01:24:28.246937+00:00",
#       "next_dagrun_data_interval_start": "2022-05-27T01:24:28.246937+00:00",
#       "owners": [
#         "airflow"
#       ],
#       "pickle_id": null,
#       "root_dag_id": null,
#       "schedule_interval": {
#         "__type": "TimeDelta",
#         "days": 1,
#         "microseconds": 0,
#         "seconds": 0
#       },
#       "scheduler_lock": null,
#       "tags": [
#         {
#           "name": "example"
#         }
#       ],
#       "timetable_description": ""
#     },
#     {
#       "dag_id": "example_time_delta_sensor_async",
#       "default_view": "grid",
#       "description": null,
#       "file_token": ".eJw9yjEOgCAMQNG7uEsHB49DKlZoLJRQEuX2OjH-l79A0kyA3C7RB5xoQAHhA-roScvmdjDutFYMN0ayudKLuQr5E6PN6Jx_IenojYpp82ijBFfH8gEpqygi.7U3x77ad42YjdALiUpbtvI76AXA",
#       "fileloc": "/home/airflow/.local/lib/python3.7/site-packages/airflow/example_dags/example_time_delta_sensor_async.py",
#       "has_import_errors": false,
#       "has_task_concurrency_limits": false,
#       "is_active": true,
#       "is_paused": true,
#       "is_subdag": false,
#       "last_expired": null,
#       "last_parsed_time": "2022-05-28T01:24:27.955991+00:00",
#       "last_pickled": null,
#       "max_active_runs": 16,
#       "max_active_tasks": 16,
#       "next_dagrun": null,
#       "next_dagrun_create_after": null,
#       "next_dagrun_data_interval_end": null,
#       "next_dagrun_data_interval_start": null,
#       "owners": [
#         "airflow"
#       ],
#       "pickle_id": null,
#       "root_dag_id": null,
#       "schedule_interval": null,
#       "scheduler_lock": null,
#       "tags": [
#         {
#           "name": "example"
#         }
#       ],
#       "timetable_description": "Never, external triggers only"
#     },
#     {
#       "dag_id": "example_trigger_controller_dag",
#       "default_view": "grid",
#       "description": null,
#       "file_token": ".eJw9ijEOgCAMAP_CLh0cfA6pWKGxUAIkyu9lYrvLnYGoiQC53qIvWFGPAsInlNGj5t0e0LjTVtA_GKitlT5MRchdGNqSXjkEqs5r7lVFJs5uyzA_Ar0ntg.WoRRK6FvIINFbZRH2DeTP_qko9w",
#       "fileloc": "/home/airflow/.local/lib/python3.7/site-packages/airflow/example_dags/example_trigger_controller_dag.py",
#       "has_import_errors": false,
#       "has_task_concurrency_limits": false,
#       "is_active": true,
#       "is_paused": true,
#       "is_subdag": false,
#       "last_expired": null,
#       "last_parsed_time": "2022-05-28T01:24:28.018191+00:00",
#       "last_pickled": null,
#       "max_active_runs": 16,
#       "max_active_tasks": 16,
#       "next_dagrun": "2021-01-01T00:00:00+00:00",
#       "next_dagrun_create_after": "2021-01-01T00:00:00+00:00",
#       "next_dagrun_data_interval_end": "2021-01-01T00:00:00+00:00",
#       "next_dagrun_data_interval_start": "2021-01-01T00:00:00+00:00",
#       "owners": [
#         "airflow"
#       ],
#       "pickle_id": null,
#       "root_dag_id": null,
#       "schedule_interval": {
#         "__type": "CronExpression",
#         "value": "@once"
#       },
#       "scheduler_lock": null,
#       "tags": [
#         {
#           "name": "example"
#         }
#       ],
#       "timetable_description": "Once, as soon as possible"
#     },
#     {
#       "dag_id": "example_trigger_target_dag",
#       "default_view": "grid",
#       "description": null,
#       "file_token": ".eJw9yjEOgCAMQNG7sEsHB49DKtbSWIRAE-X2xoXx530HqWQClHZqecBriaigskMdlsq9-g26GC0V44VMfa70Yq5K4UDuM6wJM7Vg2JjsN1-H-wBjfiX5.Yd1b0jkU1WHc0te9ifh4BiQwTOo",
#       "fileloc": "/home/airflow/.local/lib/python3.7/site-packages/airflow/example_dags/example_trigger_target_dag.py",
#       "has_import_errors": false,
#       "has_task_concurrency_limits": false,
#       "is_active": true,
#       "is_paused": true,
#       "is_subdag": false,
#       "last_expired": null,
#       "last_parsed_time": "2022-05-28T01:24:28.028800+00:00",
#       "last_pickled": null,
#       "max_active_runs": 16,
#       "max_active_tasks": 16,
#       "next_dagrun": null,
#       "next_dagrun_create_after": null,
#       "next_dagrun_data_interval_end": null,
#       "next_dagrun_data_interval_start": null,
#       "owners": [
#         "airflow"
#       ],
#       "pickle_id": null,
#       "root_dag_id": null,
#       "schedule_interval": null,
#       "scheduler_lock": null,
#       "tags": [
#         {
#           "name": "example"
#         }
#       ],
#       "timetable_description": "Never, external triggers only"
#     },
#     {
#       "dag_id": "example_weekday_branch_operator",
#       "default_view": "grid",
#       "description": null,
#       "file_token": ".eJw9yjEOgCAMQNG7uEsHB49DClYhFNoUEuX2Ojn-l79AkkqA2U6WGxxLRAbOAXSOJG1zO_Q8aFWMBS_q_0oPVmXyB179j2DYYvpsejn9TVS8KBkOMadzeQHMbimp.6NHQvBkgO2aPfwH1PzeDo0I3dIg",
#       "fileloc": "/home/airflow/.local/lib/python3.7/site-packages/airflow/example_dags/example_branch_day_of_week_operator.py",
#       "has_import_errors": false,
#       "has_task_concurrency_limits": false,
#       "is_active": true,
#       "is_paused": true,
#       "is_subdag": false,
#       "last_expired": null,
#       "last_parsed_time": "2022-05-28T01:24:26.006602+00:00",
#       "last_pickled": null,
#       "max_active_runs": 16,
#       "max_active_tasks": 16,
#       "next_dagrun": "2022-05-27T00:00:00+00:00",
#       "next_dagrun_create_after": "2022-05-28T00:00:00+00:00",
#       "next_dagrun_data_interval_end": "2022-05-28T00:00:00+00:00",
#       "next_dagrun_data_interval_start": "2022-05-27T00:00:00+00:00",
#       "owners": [
#         "airflow"
#       ],
#       "pickle_id": null,
#       "root_dag_id": null,
#       "schedule_interval": {
#         "__type": "CronExpression",
#         "value": "@daily"
#       },
#       "scheduler_lock": null,
#       "tags": [
#         {
#           "name": "example"
#         }
#       ],
#       "timetable_description": "At 00:00"
#     },
#     {
#       "dag_id": "example_xcom",
#       "default_view": "grid",
#       "description": null,
#       "file_token": ".eJw9yjEOgCAMAMC_sEsHB59jaq1AbG0jJMLv3RgvuQDZlAHLe4l9EMUIBaQc4KNle9a4QS2NF0e6MXGdlTuqC-8npjrRyTT6CD9uuiBL._PXwTXK57gFwayCLpKpkcScjSsc",
#       "fileloc": "/home/airflow/.local/lib/python3.7/site-packages/airflow/example_dags/example_xcom.py",
#       "has_import_errors": false,
#       "has_task_concurrency_limits": false,
#       "is_active": true,
#       "is_paused": true,
#       "is_subdag": false,
#       "last_expired": null,
#       "last_parsed_time": "2022-05-28T01:24:28.257276+00:00",
#       "last_pickled": null,
#       "max_active_runs": 16,
#       "max_active_tasks": 16,
#       "next_dagrun": "2021-01-01T00:00:00+00:00",
#       "next_dagrun_create_after": "2021-01-01T00:00:00+00:00",
#       "next_dagrun_data_interval_end": "2021-01-01T00:00:00+00:00",
#       "next_dagrun_data_interval_start": "2021-01-01T00:00:00+00:00",
#       "owners": [
#         "airflow"
#       ],
#       "pickle_id": null,
#       "root_dag_id": null,
#       "schedule_interval": {
#         "__type": "CronExpression",
#         "value": "@once"
#       },
#       "scheduler_lock": null,
#       "tags": [
#         {
#           "name": "example"
#         }
#       ],
#       "timetable_description": "Once, as soon as possible"
#     },
#     {
#       "dag_id": "example_xcom_args",
#       "default_view": "grid",
#       "description": null,
#       "file_token": ".eJw9yjEOgCAMAMC_sEsHB59jKlYgFNtQEuH3boyXnIMklQBze1g-8CwBGThfoLMneXd_gOVOm2IoGMlWpYFVmc4boy2MIBVbNK_T_fXRIfg.3uGNfqDZqlK3d5q33pH9DDA2x-4",
#       "fileloc": "/home/airflow/.local/lib/python3.7/site-packages/airflow/example_dags/example_xcomargs.py",
#       "has_import_errors": false,
#       "has_task_concurrency_limits": false,
#       "is_active": true,
#       "is_paused": true,
#       "is_subdag": false,
#       "last_expired": null,
#       "last_parsed_time": "2022-05-28T01:24:28.477097+00:00",
#       "last_pickled": null,
#       "max_active_runs": 16,
#       "max_active_tasks": 16,
#       "next_dagrun": null,
#       "next_dagrun_create_after": null,
#       "next_dagrun_data_interval_end": null,
#       "next_dagrun_data_interval_start": null,
#       "owners": [
#         "airflow"
#       ],
#       "pickle_id": null,
#       "root_dag_id": null,
#       "schedule_interval": null,
#       "scheduler_lock": null,
#       "tags": [
#         {
#           "name": "example"
#         }
#       ],
#       "timetable_description": "Never, external triggers only"
#     },
#     {
#       "dag_id": "example_xcom_args_with_operators",
#       "default_view": "grid",
#       "description": null,
#       "file_token": ".eJw9yjEOgCAMAMC_sEsHB59jKlYgFNtQEuH3boyXnIMklQBze1g-8CwBGThfoLMneXd_gOVOm2IoGMlWpYFVmc4boy2MIBVbNK_T_fXRIfg.3uGNfqDZqlK3d5q33pH9DDA2x-4",
#       "fileloc": "/home/airflow/.local/lib/python3.7/site-packages/airflow/example_dags/example_xcomargs.py",
#       "has_import_errors": false,
#       "has_task_concurrency_limits": false,
#       "is_active": true,
#       "is_paused": true,
#       "is_subdag": false,
#       "last_expired": null,
#       "last_parsed_time": "2022-05-28T01:24:28.477467+00:00",
#       "last_pickled": null,
#       "max_active_runs": 16,
#       "max_active_tasks": 16,
#       "next_dagrun": null,
#       "next_dagrun_create_after": null,
#       "next_dagrun_data_interval_end": null,
#       "next_dagrun_data_interval_start": null,
#       "owners": [
#         "airflow"
#       ],
#       "pickle_id": null,
#       "root_dag_id": null,
#       "schedule_interval": null,
#       "scheduler_lock": null,
#       "tags": [
#         {
#           "name": "example"
#         }
#       ],
#       "timetable_description": "Never, external triggers only"
#     },
#     {
#       "dag_id": "latest_only",
#       "default_view": "grid",
#       "description": null,
#       "file_token": ".eJw9yjEOgCAMAMC_sEsHB59DKlYkFtrYJsrv3RgvuQCXNAKsz8nyQmTJyMB1Bx1-SV_jBladFsV8YyGblT5sypQOLDbB6GSepPOIOsIPX4cjQg.vZQ7BGWV3IO6BTZ4qwo6v1TA7As",
#       "fileloc": "/home/airflow/.local/lib/python3.7/site-packages/airflow/example_dags/example_latest_only.py",
#       "has_import_errors": false,
#       "has_task_concurrency_limits": false,
#       "is_active": true,
#       "is_paused": true,
#       "is_subdag": false,
#       "last_expired": null,
#       "last_parsed_time": "2022-05-28T01:24:27.469655+00:00",
#       "last_pickled": null,
#       "max_active_runs": 16,
#       "max_active_tasks": 16,
#       "next_dagrun": "2022-05-27T21:24:27.469810+00:00",
#       "next_dagrun_create_after": "2022-05-28T01:24:27.469810+00:00",
#       "next_dagrun_data_interval_end": "2022-05-28T01:24:27.469810+00:00",
#       "next_dagrun_data_interval_start": "2022-05-27T21:24:27.469810+00:00",
#       "owners": [
#         "airflow"
#       ],
#       "pickle_id": null,
#       "root_dag_id": null,
#       "schedule_interval": {
#         "__type": "TimeDelta",
#         "days": 0,
#         "microseconds": 0,
#         "seconds": 14400
#       },
#       "scheduler_lock": null,
#       "tags": [
#         {
#           "name": "example2"
#         },
#         {
#           "name": "example3"
#         }
#       ],
#       "timetable_description": ""
#     },
#     {
#       "dag_id": "latest_only_with_trigger",
#       "default_view": "grid",
#       "description": null,
#       "file_token": ".eJw9yjEOgCAMAMC_sEsHB59DKlZoLJRAE-T3bo6XnIOshQC536ITvGhEAeET2rKsdfcHDDbaGsYHE42_0oulCYUL0_ghaDQsaJUVJlsO1jkl6r4t9wFV1iiw.RwgZSikh_--oX01vyaFAw7GERJk",
#       "fileloc": "/home/airflow/.local/lib/python3.7/site-packages/airflow/example_dags/example_latest_only_with_trigger.py",
#       "has_import_errors": false,
#       "has_task_concurrency_limits": false,
#       "is_active": true,
#       "is_paused": true,
#       "is_subdag": false,
#       "last_expired": null,
#       "last_parsed_time": "2022-05-28T01:24:27.505122+00:00",
#       "last_pickled": null,
#       "max_active_runs": 16,
#       "max_active_tasks": 16,
#       "next_dagrun": "2022-05-27T21:24:27.505255+00:00",
#       "next_dagrun_create_after": "2022-05-28T01:24:27.505255+00:00",
#       "next_dagrun_data_interval_end": "2022-05-28T01:24:27.505255+00:00",
#       "next_dagrun_data_interval_start": "2022-05-27T21:24:27.505255+00:00",
#       "owners": [
#         "airflow"
#       ],
#       "pickle_id": null,
#       "root_dag_id": null,
#       "schedule_interval": {
#         "__type": "TimeDelta",
#         "days": 0,
#         "microseconds": 0,
#         "seconds": 14400
#       },
#       "scheduler_lock": null,
#       "tags": [
#         {
#           "name": "example3"
#         }
#       ],
#       "timetable_description": ""
#     },
#     {
#       "dag_id": "tutorial",
#       "default_view": "grid",
#       "description": "A simple tutorial DAG",
#       "file_token": ".eJw9yjEOgCAMAMC_sEsHB59jKlZoLLaBGuX3bt58AYpWAuR2iD4QRRMKCG9gw4tec1ygs9NkmE7M1P9KL1YTWnfMHfx2bYwSbYQP75YevQ.bWdV3geC7pWvSzyWEvnFvgCberU",
#       "fileloc": "/home/airflow/.local/lib/python3.7/site-packages/airflow/example_dags/tutorial.py",
#       "has_import_errors": false,
#       "has_task_concurrency_limits": false,
#       "is_active": true,
#       "is_paused": true,
#       "is_subdag": false,
#       "last_expired": null,
#       "last_parsed_time": "2022-05-28T01:24:28.326399+00:00",
#       "last_pickled": null,
#       "max_active_runs": 16,
#       "max_active_tasks": 16,
#       "next_dagrun": "2022-05-27T01:24:28.326567+00:00",
#       "next_dagrun_create_after": "2022-05-28T01:24:28.326567+00:00",
#       "next_dagrun_data_interval_end": "2022-05-28T01:24:28.326567+00:00",
#       "next_dagrun_data_interval_start": "2022-05-27T01:24:28.326567+00:00",
#       "owners": [
#         "airflow"
#       ],
#       "pickle_id": null,
#       "root_dag_id": null,
#       "schedule_interval": {
#         "__type": "TimeDelta",
#         "days": 1,
#         "microseconds": 0,
#         "seconds": 0
#       },
#       "scheduler_lock": null,
#       "tags": [
#         {
#           "name": "example"
#         }
#       ],
#       "timetable_description": ""
#     },
#     {
#       "dag_id": "tutorial_etl_dag",
#       "default_view": "grid",
#       "description": "ETL DAG tutorial",
#       "file_token": ".eJw9yjEOgCAMAMC_sEsHB59DKlZoLJZAjfJ74-J6OQdZCwFy20Vv8KIRBYRXqMOynrNfoLPRVDEemKj_lR4sVShsmDrYZdoYJZDJJ74O9wL24SHs.Yl2aCP6mg_2vrYp5Wa39dFhRFck",
#       "fileloc": "/home/airflow/.local/lib/python3.7/site-packages/airflow/example_dags/tutorial_etl_dag.py",
#       "has_import_errors": false,
#       "has_task_concurrency_limits": false,
#       "is_active": true,
#       "is_paused": true,
#       "is_subdag": false,
#       "last_expired": null,
#       "last_parsed_time": "2022-05-28T01:24:28.395798+00:00",
#       "last_pickled": null,
#       "max_active_runs": 16,
#       "max_active_tasks": 16,
#       "next_dagrun": null,
#       "next_dagrun_create_after": null,
#       "next_dagrun_data_interval_end": null,
#       "next_dagrun_data_interval_start": null,
#       "owners": [
#         "airflow"
#       ],
#       "pickle_id": null,
#       "root_dag_id": null,
#       "schedule_interval": null,
#       "scheduler_lock": null,
#       "tags": [
#         {
#           "name": "example"
#         }
#       ],
#       "timetable_description": "Never, external triggers only"
#     },
#     {
#       "dag_id": "tutorial_taskflow_api_etl",
#       "default_view": "grid",
#       "description": null,
#       "file_token": ".eJw9yjESQEAMBdC76G0KhePsfASZDcnYGNzeaNTvNbTaxgQ5ZrWLktoIJZWB_InV9i71VCW4dYwFC9e_8o3NlfOEpVKcYYdAc6CWjzNcMocmf5oXQNYlxA.C-DILqrniCs3YViPW2Cgn8cx2P0",
#       "fileloc": "/home/airflow/.local/lib/python3.7/site-packages/airflow/example_dags/tutorial_taskflow_api_etl.py",
#       "has_import_errors": false,
#       "has_task_concurrency_limits": false,
#       "is_active": true,
#       "is_paused": true,
#       "is_subdag": false,
#       "last_expired": null,
#       "last_parsed_time": "2022-05-28T01:24:28.619747+00:00",
#       "last_pickled": null,
#       "max_active_runs": 16,
#       "max_active_tasks": 16,
#       "next_dagrun": null,
#       "next_dagrun_create_after": null,
#       "next_dagrun_data_interval_end": null,
#       "next_dagrun_data_interval_start": null,
#       "owners": [
#         "airflow"
#       ],
#       "pickle_id": null,
#       "root_dag_id": null,
#       "schedule_interval": null,
#       "scheduler_lock": null,
#       "tags": [
#         {
#           "name": "example"
#         }
#       ],
#       "timetable_description": "Never, external triggers only"
#     },
#     {
#       "dag_id": "tutorial_taskflow_api_etl_virtualenv",
#       "default_view": "grid",
#       "description": null,
#       "file_token": ".eJw9yjESg0AIBdC72GcpUuQ4zNcQZURhdtHo7R0b6_c6mnwRgtaf-Z-K-QAj057izMnXd_lQ05RXYJgxSnuqHFjChL8YG-WWXhXGiTbfzAhlSeNda24wWfcSZ3cBAZsqcw.ax2Pp_hfNkprdSp23ltk3MIMdM4",
#       "fileloc": "/home/airflow/.local/lib/python3.7/site-packages/airflow/example_dags/tutorial_taskflow_api_etl_virtualenv.py",
#       "has_import_errors": false,
#       "has_task_concurrency_limits": false,
#       "is_active": true,
#       "is_paused": true,
#       "is_subdag": false,
#       "last_expired": null,
#       "last_parsed_time": "2022-05-28T01:24:28.709711+00:00",
#       "last_pickled": null,
#       "max_active_runs": 16,
#       "max_active_tasks": 16,
#       "next_dagrun": null,
#       "next_dagrun_create_after": null,
#       "next_dagrun_data_interval_end": null,
#       "next_dagrun_data_interval_start": null,
#       "owners": [
#         "airflow"
#       ],
#       "pickle_id": null,
#       "root_dag_id": null,
#       "schedule_interval": null,
#       "scheduler_lock": null,
#       "tags": [
#         {
#           "name": "example"
#         }
#       ],
#       "timetable_description": "Never, external triggers only"
#     }
#   ],
#   "total_entries": 34
# }

# %%
docker-compose down && docker-compose up

# %%
# !docker ps
# Out:
# CONTAINER ID   IMAGE                  COMMAND                  CREATED         STATUS                   PORTS                                       NAMES
# c16081551801   apache/airflow:2.3.1   "/usr/bin/dumb-init …"   2 minutes ago   Up 2 minutes (healthy)   0.0.0.0:8080->8080/tcp, :::8080->8080/tcp   airflow-docker-airflow-webserver-1
# 14f380561445   apache/airflow:2.3.1   "/usr/bin/dumb-init …"   2 minutes ago   Up 2 minutes (healthy)   8080/tcp                                    airflow-docker-airflow-triggerer-1
# 4dbfb4d1c714   apache/airflow:2.3.1   "/usr/bin/dumb-init …"   2 minutes ago   Up 2 minutes (healthy)   8080/tcp                                    airflow-docker-airflow-worker-1
# de805c8e1470   apache/airflow:2.3.1   "/usr/bin/dumb-init …"   2 minutes ago   Up 2 minutes (healthy)   8080/tcp                                    airflow-docker-airflow-scheduler-1
# 2c5212aa3307   postgres:13            "docker-entrypoint.s…"   2 minutes ago   Up 2 minutes (healthy)   5432/tcp                                    airflow-docker-postgres-1
# d1b1e1827d30   redis:latest           "docker-entrypoint.s…"   2 minutes ago   Up 2 minutes (healthy)   6379/tcp                                    airflow-docker-redis-1
