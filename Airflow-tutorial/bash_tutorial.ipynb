# %%
# !sudo git clone https://github.com/tuanavu/airflow-tutorial.git
# Out:
# Cloning into 'airflow-tutorial'...
# remote: Enumerating objects: 220, done.
# remote: Counting objects: 100% (81/81), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 220 (delta 67), reused 61 (delta 61), pack-reused 139
# Receiving objects: 100% (220/220), 156.27 KiB | 7.44 MiB/s, done.
# Resolving deltas: 100% (84/84), done.

# %%
# !sudo apt-get install docker-engine -y
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Package docker-engine is not available, but is referred to by another package.
# This may mean that the package is missing, has been obsoleted, or
# is only available from another source
# However the following packages replace it:
#   docker-ce
#
# E: Package 'docker-engine' has no installation candidate

# %%
# !wget "https://desktop.docker.com/linux/main/amd64/docker-desktop-4.8.1-amd64.deb?utm_source=docker&utm_medium=webreferral&utm_campaign=docs-driven-download-linux-amd64"
# Out:
# --2022-05-28 00:14:43--  https://desktop.docker.com/linux/main/amd64/docker-desktop-4.8.1-amd64.deb?utm_source=docker&utm_medium=webreferral&utm_campaign=docs-driven-download-linux-amd64
# Resolving desktop.docker.com (desktop.docker.com)... 99.86.4.36, 99.86.4.71, 99.86.4.117, ...
# Connecting to desktop.docker.com (desktop.docker.com)|99.86.4.36|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 388679164 (371M)
# Saving to: ‘docker-desktop-4.8.1-amd64.deb?utm_source=docker&utm_medium=webreferral&utm_campaign=docs-driven-download-linux-amd64’
#
# docker-desktop-4.8. 100%[===================>] 370.67M  92.4MB/s    in 4.1s
#
# 2022-05-28 00:14:47 (90.7 MB/s) - ‘docker-desktop-4.8.1-amd64.deb?utm_source=docker&utm_medium=webreferral&utm_campaign=docs-driven-download-linux-amd64’ saved [388679164/388679164]

# %%
# !ls
# Out:
# airflow-tutorial  bash.sh			  README.md
# bash.ipynb	  docker-desktop-4.8.1-amd64.deb

# %%
# !sudo dpkg -i docker-desktop-4.8.1-amd64.deb
# Out:
# Selecting previously unselected package docker-desktop.
# (Reading database ... 36033 files and directories currently installed.)
# Preparing to unpack docker-desktop-4.8.1-amd64.deb ...
# Unpacking docker-desktop (4.8.1-78998) ...
# dpkg: dependency problems prevent configuration of docker-desktop:
#  docker-desktop depends on qemu-system-x86 (>= 5.2.0); however:
#   Package qemu-system-x86 is not installed.
#  docker-desktop depends on docker-ce-cli; however:
#   Package docker-ce-cli is not installed.
#  docker-desktop depends on pass; however:
#   Package pass is not installed.
#  docker-desktop depends on desktop-file-utils; however:
#   Package desktop-file-utils is not installed.
#  docker-desktop depends on libgtk-3-0; however:
#   Package libgtk-3-0 is not installed.
#  docker-desktop depends on libx11-xcb1; however:
#   Package libx11-xcb1 is not installed.
#
# dpkg: error processing package docker-desktop (--install):
#  dependency problems - leaving unconfigured
# Processing triggers for mime-support (3.64ubuntu1) ...
# Errors were encountered while processing:
#  docker-desktop

# %%
# !sudo apt --fix-broken install
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Correcting dependencies... Done
# The following additional packages will be installed:
#   acl adwaita-icon-theme at-spi2-core cpu-checker desktop-file-utils
#   docker-ce-cli docker-scan-plugin gstreamer1.0-plugins-base
#   gstreamer1.0-plugins-good gstreamer1.0-x gtk-update-icon-cache
#   humanity-icon-theme ibverbs-providers ipxe-qemu
#   ipxe-qemu-256k-compat-efi-roms libaa1 libaio1 libasyncns0 libatk-bridge2.0-0
#   libatk1.0-0 libatk1.0-data libatspi2.0-0 libavahi-client3
#   libavahi-common-data libavahi-common3 libavc1394-0 libboost-iostreams1.71.0
#   libboost-thread1.71.0 libbrlapi0.7 libcaca0 libcacard0 libcdparanoia0
#   libcolord2 libcups2 libdrm-common libdrm2 libdv4 libepoxy0 libfdt1 libflac8
#   libgbm1 libgstreamer-plugins-base1.0-0 libgstreamer-plugins-good1.0-0
#   libgtk-3-0 libgtk-3-bin libgtk-3-common libgudev-1.0-0 libibverbs1
#   libiec61883-0 libiscsi7 libjack-jackd2-0 libjson-glib-1.0-0
#   libjson-glib-1.0-common libmp3lame0 libmpg123-0 libnl-3-200
#   libnl-route-3-200 libnspr4 libnss3 libnuma1 libopus0 liborc-0.4-0
#   libpcsclite1 libpmem1 libpulse0 libqrencode4 librados2 libraw1394-11 librbd1
#   librdmacm1 librest-0.7-0 libsamplerate0 libshout3 libslang2 libslirp0
#   libsndfile1 libsoup-gnome2.4-1 libspeex1 libspice-server1 libtag1v5
#   libtag1v5-vanilla libtheora0 libtwolame0 libusb-1.0-0 libusbredirparser1
#   libv4l-0 libv4lconvert0 libvirglrenderer1 libvisual-0.4-0 libvorbisenc2
#   libvpx6 libvte-2.91-0 libvte-2.91-common libwavpack1 libwayland-client0
#   libwayland-cursor0 libwayland-egl1 libwayland-server0 libwrap0 libx11-xcb1
#   libxcomposite1 libxcursor1 libxdamage1 libxfixes3 libxi6 libxinerama1
#   libxkbcommon0 libxmu6 libxmuu1 libxrandr2 libxtst6 libxv1 msr-tools ovmf
#   pass qemu-block-extra qemu-system-common qemu-system-data qemu-system-gui
#   qemu-system-x86 qemu-utils qrencode seabios sharutils tree ubuntu-mono xauth
#   xclip xkb-data
# Suggested packages:
#   gvfs colord cups-common libdv-bin oss-compat libvisual-0.4-plugins jackd2
#   opus-tools pcscd pulseaudio libraw1394-doc speex gstreamer1.0-plugins-ugly
#   python libxml-simple-perl ruby samba vde2 debootstrap sharutils-doc
#   bsd-mailx | mailx
# The following NEW packages will be installed:
#   acl adwaita-icon-theme at-spi2-core cpu-checker desktop-file-utils
#   docker-ce-cli docker-scan-plugin gstreamer1.0-plugins-base
#   gstreamer1.0-plugins-good gstreamer1.0-x gtk-update-icon-cache
#   humanity-icon-theme ibverbs-providers ipxe-qemu
#   ipxe-qemu-256k-compat-efi-roms libaa1 libaio1 libasyncns0 libatk-bridge2.0-0
#   libatk1.0-0 libatk1.0-data libatspi2.0-0 libavahi-client3
#   libavahi-common-data libavahi-common3 libavc1394-0 libboost-iostreams1.71.0
#   libboost-thread1.71.0 libbrlapi0.7 libcaca0 libcacard0 libcdparanoia0
#   libcolord2 libcups2 libdrm-common libdrm2 libdv4 libepoxy0 libfdt1 libflac8
#   libgbm1 libgstreamer-plugins-base1.0-0 libgstreamer-plugins-good1.0-0
#   libgtk-3-0 libgtk-3-bin libgtk-3-common libgudev-1.0-0 libibverbs1
#   libiec61883-0 libiscsi7 libjack-jackd2-0 libjson-glib-1.0-0
#   libjson-glib-1.0-common libmp3lame0 libmpg123-0 libnl-3-200
#   libnl-route-3-200 libnspr4 libnss3 libnuma1 libopus0 liborc-0.4-0
#   libpcsclite1 libpmem1 libpulse0 libqrencode4 librados2 libraw1394-11 librbd1
#   librdmacm1 librest-0.7-0 libsamplerate0 libshout3 libslang2 libslirp0
#   libsndfile1 libsoup-gnome2.4-1 libspeex1 libspice-server1 libtag1v5
#   libtag1v5-vanilla libtheora0 libtwolame0 libusb-1.0-0 libusbredirparser1
#   libv4l-0 libv4lconvert0 libvirglrenderer1 libvisual-0.4-0 libvorbisenc2
#   libvpx6 libvte-2.91-0 libvte-2.91-common libwavpack1 libwayland-client0
#   libwayland-cursor0 libwayland-egl1 libwayland-server0 libwrap0 libx11-xcb1
#   libxcomposite1 libxcursor1 libxdamage1 libxfixes3 libxi6 libxinerama1
#   libxkbcommon0 libxmu6 libxmuu1 libxrandr2 libxtst6 libxv1 msr-tools ovmf
#   pass qemu-block-extra qemu-system-common qemu-system-data qemu-system-gui
#   qemu-system-x86 qemu-utils qrencode seabios sharutils tree ubuntu-mono xauth
#   xclip xkb-data
# 0 upgraded, 129 newly installed, 0 to remove and 25 not upgraded.
# 1 not fully installed or removed.
# Need to get 84.2 MB of archives.
# After this operation, 350 MB of additional disk space will be used.
# Do you want to continue? [Y/n] ^C

# %%
# !sudo apt-get install docker-ce-cli
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# You might want to run 'apt --fix-broken install' to correct these.
# The following packages have unmet dependencies:
#  docker-desktop : Depends: qemu-system-x86 (>= 5.2.0) but it is not going to be installed
#                   Depends: pass but it is not going to be installed
#                   Depends: desktop-file-utils but it is not going to be installed
#                   Depends: libgtk-3-0 but it is not going to be installed
#                   Depends: libx11-xcb1 but it is not going to be installed
# E: Unmet dependencies. Try 'apt --fix-broken install' with no packages (or specify a solution).

# %%
cat /etc/os-release
# Out:
# NAME="Ubuntu"
# VERSION="20.04.4 LTS (Focal Fossa)"
# ID=ubuntu
# ID_LIKE=debian
# PRETTY_NAME="Ubuntu 20.04.4 LTS"
# VERSION_ID="20.04"
# HOME_URL="https://www.ubuntu.com/"
# SUPPORT_URL="https://help.ubuntu.com/"
# BUG_REPORT_URL="https://bugs.launchpad.net/ubuntu/"
# PRIVACY_POLICY_URL="https://www.ubuntu.com/legal/terms-and-policies/privacy-policy"
# VERSION_CODENAME=focal
# UBUNTU_CODENAME=focal

# %%
# !sudo apt-get remove docker docker-engine docker.io containerd runc
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Package 'docker-engine' is not installed, so not removed
# Package 'docker' is not installed, so not removed
# Package 'containerd' is not installed, so not removed
# Package 'runc' is not installed, so not removed
# Package 'docker.io' is not installed, so not removed
# 0 upgraded, 0 newly installed, 0 to remove and 25 not upgraded.

# %% [markdown]
# # Install Docker

# %%
# no need to run
# !sudo apt-get update
# !sudo apt-get install \
    ca-certificates \
    curl \
    gnupg \
    lsb-release
# Out:
# Hit:2 http://archive.ubuntu.com/ubuntu focal InRelease
# Get:3 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Hit:4 http://ppa.launchpad.net/git-core/ppa/ubuntu focal InRelease
# Get:5 https://download.docker.com/linux/ubuntu focal InRelease [57.7 kB]
# Get:6 http://ppa.launchpad.net/ondrej/apache2/ubuntu focal InRelease [23.8 kB]
# Get:1 https://apt.llvm.org/focal llvm-toolchain-focal InRelease [6,824 B]
# Get:7 http://archive.ubuntu.com/ubuntu focal-backports InRelease [108 kB]
# Get:8 http://ppa.launchpad.net/ondrej/nginx-mainline/ubuntu focal InRelease [23.8 kB]
# Get:9 http://ppa.launchpad.net/ondrej/php/ubuntu focal InRelease [23.9 kB]
# Get:10 http://security.ubuntu.com/ubuntu focal-security InRelease [114 kB]
# Get:11 https://download.docker.com/linux/ubuntu focal/stable amd64 Packages [18.6 kB]
# Get:12 http://ppa.launchpad.net/ondrej/apache2/ubuntu focal/main amd64 Packages [5,149 B]
# Get:13 http://archive.ubuntu.com/ubuntu focal-updates/restricted amd64 Packages [1,285 kB]
# Get:14 https://apt.llvm.org/focal llvm-toolchain-focal/main amd64 Packages [12.4 kB]
# Get:15 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1,161 kB]
# Get:16 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [2,280 kB]
# Get:17 http://archive.ubuntu.com/ubuntu focal-backports/universe amd64 Packages [27.1 kB]
# Get:18 http://archive.ubuntu.com/ubuntu focal-backports/main amd64 Packages [53.8 kB]
# Get:19 http://ppa.launchpad.net/ondrej/nginx-mainline/ubuntu focal/main amd64 Packages [6,422 B]
# Get:20 http://ppa.launchpad.net/ondrej/php/ubuntu focal/main amd64 Packages [169 kB]
# Get:21 http://security.ubuntu.com/ubuntu focal-security/restricted amd64 Packages [1,205 kB]
# Get:22 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [874 kB]
# Get:23 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [1,850 kB]
# Fetched 9,419 kB in 1s (6,921 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# lsb-release is already the newest version (11.1.0ubuntu2).
# lsb-release set to manually installed.
# ca-certificates is already the newest version (20210119~20.04.2).
# curl is already the newest version (7.68.0-1ubuntu2.11).
# gnupg is already the newest version (2.2.19-3ubuntu2.1).
# 0 upgraded, 0 newly installed, 0 to remove and 25 not upgraded.

# %%
# !sudo mkdir -p /etc/apt/keyrings

# %%
# !curl -fsSL https://download.docker.com/linux/ubuntu/gpg | sudo gpg --dearmor -o /etc/apt/keyrings/docker.gpg

# %%
# !echo \
  "deb [arch=$(dpkg --print-architecture) signed-by=/etc/apt/keyrings/docker.gpg] https://download.docker.com/linux/ubuntu \
  $(lsb_release -cs) stable" | sudo tee /etc/apt/sources.list.d/docker.list > /dev/null

# %%
! sudo apt-get update
# Out:
# Hit:2 http://security.ubuntu.com/ubuntu focal-security InRelease
# Hit:3 http://ppa.launchpad.net/git-core/ppa/ubuntu focal InRelease
# Hit:4 https://download.docker.com/linux/ubuntu focal InRelease
# Hit:5 http://ppa.launchpad.net/ondrej/apache2/ubuntu focal InRelease
# Hit:1 https://apt.llvm.org/focal llvm-toolchain-focal InRelease
# Hit:6 http://ppa.launchpad.net/ondrej/nginx-mainline/ubuntu focal InRelease
# Hit:7 http://ppa.launchpad.net/ondrej/php/ubuntu focal InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu focal InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu focal-updates InRelease
# Hit:10 http://archive.ubuntu.com/ubuntu focal-backports InRelease
# Reading package lists... Done

# %%
# run in terminal
sudo apt-get install docker-ce docker-ce-cli containerd.io docker-compose-plugin
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   apparmor docker-ce-rootless-extras docker-scan-plugin pigz slirp4netns
# Suggested packages:
#   apparmor-profiles-extra apparmor-utils aufs-tools cgroupfs-mount
#   | cgroup-lite
# The following NEW packages will be installed:
#   apparmor containerd.io docker-ce docker-ce-cli docker-ce-rootless-extras
#   docker-compose-plugin docker-scan-plugin pigz slirp4netns
# 0 upgraded, 9 newly installed, 0 to remove and 25 not upgraded.
# Need to get 109 MB of archives.
# After this operation, 451 MB of additional disk space will be used.
# Do you want to continue? [Y/n] ^C

# %%
# no need to run
# !apt-cache madison docker-ce

# %%
# no need to run
# !sudo apt-get install docker-ce="5:20.10.16~3-0~ubuntu-focal"  docker-ce-cli="5:20.10.16~3-0~ubuntu-focal" containerd.io docker-compose-plugin
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# containerd.io is already the newest version (1.6.4-1).
# docker-ce-cli is already the newest version (5:20.10.16~3-0~ubuntu-focal).
# docker-ce is already the newest version (5:20.10.16~3-0~ubuntu-focal).
# docker-compose-plugin is already the newest version (2.5.0~ubuntu-focal).
# 0 upgraded, 0 newly installed, 0 to remove and 25 not upgraded.

# %%
# !sudo docker run hello-world
# Out:
# Hello from Docker!
# This message shows that your installation appears to be working correctly.
#
# To generate this message, Docker took the following steps:
#  1. The Docker client contacted the Docker daemon.
#  2. The Docker daemon pulled the "hello-world" image from the Docker Hub.
#     (amd64)
#  3. The Docker daemon created a new container from that image which runs the
#     executable that produces the output you are currently reading.
#  4. The Docker daemon streamed that output to the Docker client, which sent it
#     to your terminal.
#
# To try something more ambitious, you can run an Ubuntu container with:
#  $ docker run -it ubuntu bash
#
# Share images, automate workflows, and more with a free Docker ID:
#  https://hub.docker.com/
#
# For more examples and ideas, visit:
#  https://docs.docker.com/get-started/

# %%
# !docker run -it ubuntu bash
# Out:
# Unable to find image 'ubuntu:latest' locally
# latest: Pulling from library/ubuntu
#
# Digest: sha256:26c68657ccce2cb0a31b330cb0be2b5e108d467f641c62e13ab40cbec258c68d[1A
# Status: Downloaded newer image for ubuntu:latest
# oot@fa7d74ee3a69: /root@fa7d74ee3a69:/# 9:/# ^C
#
# root@fa7d74ee3a69:/#

# %%
# !sudo docker run hello-world
# Out:
# Hello from Docker!
# This message shows that your installation appears to be working correctly.
#
# To generate this message, Docker took the following steps:
#  1. The Docker client contacted the Docker daemon.
#  2. The Docker daemon pulled the "hello-world" image from the Docker Hub.
#     (amd64)
#  3. The Docker daemon created a new container from that image which runs the
#     executable that produces the output you are currently reading.
#  4. The Docker daemon streamed that output to the Docker client, which sent it
#     to your terminal.
#
# To try something more ambitious, you can run an Ubuntu container with:
#  $ docker run -it ubuntu bash
#
# Share images, automate workflows, and more with a free Docker ID:
#  https://hub.docker.com/
#
# For more examples and ideas, visit:
#  https://docs.docker.com/get-started/

# %%
# !pwd
# Out:
# /workspace/AirflowDAG/Airflow-tutorial

# %%
# !docker-compose up -d
# Out:
# [+] Running 0/0
#  ⠋ webserver Pulling                                                       0.1s
#  ⠋ postgres Pulling                                                        0.1s
# [+] Running 0/2
#  ⠙ webserver Pulling                                                       0.2s
#  ⠙ postgres Pulling                                                        0.2s
# [+] Running 0/2
#  ⠹ webserver Pulling                                                       0.3s
#  ⠹ postgres Pulling                                                        0.3s
# [+] Running 0/2
#  ⠸ webserver Pulling                                                       0.4s
#  ⠸ postgres Pulling                                                        0.4s
# [+] Running 0/2
#  ⠼ webserver Pulling                                                       0.5s
#  ⠼ postgres Pulling                                                        0.5s
# [+] Running 0/2
#  ⠴ webserver Pulling                                                       0.6s
#  ⠴ postgres Pulling                                                        0.6s
# [+] Running 0/2
#  ⠦ webserver Pulling                                                       0.7s
#  ⠦ postgres Pulling                                                        0.7s
# [+] Running 0/2
#  ⠧ webserver Pulling                                                       0.8s
#  ⠧ postgres Pulling                                                        0.8s
# [+] Running 0/2
#  ⠇ webserver Pulling                                                       0.9s
#  ⠇ postgres Pulling                                                        0.9s
# [+] Running 0/2
#  ⠏ webserver Pulling                                                       1.0s
#  ⠏ postgres Pulling                                                        1.0s
# [+] Running 0/2
#  ⠋ webserver Pulling                                                       1.1s
#  ⠋ postgres Pulling                                                        1.1s
# [+] Running 0/2
#  ⠙ webserver Pulling                                                       1.2s
#  ⠙ postgres Pulling                                                        1.2s
# [+] Running 0/2
#  ⠹ webserver Pulling                                                       1.3s
#  ⠹ postgres Pulling                                                        1.3s
# [+] Running 0/2
#  ⠸ webserver Pulling                                                       1.4s
#  ⠸ postgres Pulling                                                        1.4s
# [+] Running 0/2
#  ⠼ webserver Pulling                                                       1.5s
#    ⠋ f5d23c7fed46 Pulling fs layer                                         0.0s
#    ⠋ bac1b0ed365c Pulling fs layer                                         0.0s
#    ⠋ 58e672959ab0 Pulling fs layer                                         0.0s
#    ⠋ 73d4f701d230 Waiting                                                  0.0s
#    ⠋ 49ba2829f348 Waiting                                                  0.0s
#    ⠋ 7879192fb664 Waiting                                                  0.0s
#    ⠋ 4dc5b89c560e Waiting                                                  0.0s
#    ⠋ bb8547bce572 Waiting                                                  0.0s
#    ⠋ d71939ab0198 Waiting                                                  0.0s
#  ⠼ postgres Pulling                                                        1.5s
# [+] Running 0/11
#  ⠴ webserver Pulling                                                       1.6s
#    ⠙ f5d23c7fed46 Pulling fs layer                                         0.1s
#    ⠙ bac1b0ed365c Pulling fs layer                                         0.1s
#    ⠙ 58e672959ab0 Pulling fs layer                                         0.1s
#    ⠙ 73d4f701d230 Waiting                                                  0.1s
#    ⠙ 49ba2829f348 Waiting                                                  0.1s
#    ⠙ 7879192fb664 Waiting                                                  0.1s
#    ⠙ 4dc5b89c560e Waiting                                                  0.1s
#    ⠙ bb8547bce572 Waiting                                                  0.1s
#    ⠙ d71939ab0198 Waiting                                                  0.1s
#  ⠴ postgres Pulling                                                        1.6s
# [+] Running 0/11
#  ⠦ webserver Pulling                                                       1.7s
#    ⠹ f5d23c7fed46 Pulling fs layer                                         0.2s
#    ⠹ bac1b0ed365c Pulling fs layer                                         0.2s
#    ⠹ 58e672959ab0 Pulling fs layer                                         0.2s
#    ⠹ 73d4f701d230 Waiting                                                  0.2s
#    ⠹ 49ba2829f348 Waiting                                                  0.2s
#    ⠹ 7879192fb664 Waiting                                                  0.2s
#    ⠹ 4dc5b89c560e Waiting                                                  0.2s
#    ⠹ bb8547bce572 Waiting                                                  0.2s
#    ⠹ d71939ab0198 Waiting                                                  0.2s
#  ⠦ postgres Pulling                                                        1.7s
# [+] Running 0/11
#  ⠧ webserver Pulling                                                       1.8s
#    ⠸ f5d23c7fed46 Pulling fs layer                                         0.3s
#    ⠸ bac1b0ed365c Pulling fs layer                                         0.3s
#    ⠸ 58e672959ab0 Pulling fs layer                                         0.3s
#    ⠸ 73d4f701d230 Waiting                                                  0.3s
#    ⠸ 49ba2829f348 Waiting                                                  0.3s
#    ⠸ 7879192fb664 Waiting                                                  0.3s
#    ⠸ 4dc5b89c560e Waiting                                                  0.3s
#    ⠸ bb8547bce572 Waiting                                                  0.3s
#    ⠸ d71939ab0198 Waiting                                                  0.3s
#  ⠧ postgres Pulling                                                        1.8s
# [+] Running 0/11
#  ⠇ webserver Pulling                                                       1.9s
#    ⠼ f5d23c7fed46 Downloading  278.5kB/27.09MB                             0.4s
#    ⠼ bac1b0ed365c Downloading  28.75kB/2.748MB                             0.4s
#    ⠼ 58e672959ab0 Downloading  278.5kB/26.61MB                             0.4s
#    ⠼ 73d4f701d230 Waiting                                                  0.4s
#    ⠼ 49ba2829f348 Waiting                                                  0.4s
#    ⠼ 7879192fb664 Waiting                                                  0.4s
#    ⠼ 4dc5b89c560e Waiting                                                  0.4s
#    ⠼ bb8547bce572 Waiting                                                  0.4s
#    ⠼ d71939ab0198 Waiting                                                  0.4s
#  ⠇ postgres Pulling                                                        1.9s
#    ⠋ 1cb79db8a9e7 Waiting                                                  0.0s
#    ⠋ f6bae7873dd7 Waiting                                                  0.0s
#    ⠋ 8f7722dc50a7 Waiting                                                  0.0s
#    ⠋ e8622b8cb6f3 Waiting                                                  0.0s
#    ⠋ d6d74bba3a57 Waiting                                                  0.0s
#    ⠋ 874d4d2a09fd Waiting                                                  0.0s
#    ⠋ 2d87c3a4038c Waiting                                                  0.0s
#    ⠋ f955a6cf127b Waiting                                                  0.0s
#    ⠋ f62dc55c568d Waiting                                                  0.0s
#    ⠋ 4e2c4902efbd Pulling fs layer                                         0.0s
#    ⠋ 01c676df543a Waiting                                                  0.0s
#    ⠋ 1e3d335ef0b7 Waiting                                                  0.0s
#    ⠋ 11087f2b0d87 Waiting                                                  0.0s
#    ⠋ 4b9a74ac6ea0 Waiting                                                  0.0s
# [+] Running 0/25
#    ⠸ 7879192fb664 Download complete                                        2.3s
#    ⠸ 4dc5b89c560e Download complete                                        2.3s
#    ⠸ bb8547bce572 Download complete                                        2.3s
#    ⠸ d71939ab0198 Download complete                                        2.3s
#  ⠧ postgres Pulling                                                        3.8s
#    ⠏ 1cb79db8a9e7 Extracting  8.487MB/22.53MB                              1.9s
#    ⠏ f6bae7873dd7 Download complete                                        1.9s
#    ⠏ 8f7722dc50a7 Waiting                                                  1.9s
#    ⠏ e8622b8cb6f3 Waiting                                                  1.9s
#    ⠏ d6d74bba3a57 Waiting                                                  1.9s
#    ⠏ 874d4d2a09fd Waiting                                                  1.9s
#    ⠏ 2d87c3a4038c Waiting                                                  1.9s
#    ⠏ f955a6cf127b Waiting                                                  1.9s
#    ⠏ f62dc55c568d Waiting                                                  1.9s
#    ⠏ 4e2c4902efbd Pulling fs layer                                         1.9s
#    ⠏ 01c676df543a Waiting                                                  1.9s
#    ⠏ 1e3d335ef0b7 Waiting                                                  1.9s
#    ⠏ 11087f2b0d87 Waiting                                                  1.9s
#    ⠏ 4b9a74ac6ea0 Waiting                                                  1.9s
# [+] Running 2/25
#  ⠇ webserver Pulling                                                       3.9s
#    ⠿ f5d23c7fed46 Pull complete                                            1.2s
#    ⠿ bac1b0ed365c Pull complete                                            1.6s
#    ⠼ 58e672959ab0 Extracting  26.61MB/26.61MB                              2.4s
#    ⠼ 73d4f701d230 Download complete                                        2.4s
#    ⠼ 49ba2829f348 Download complete                                        2.4s
#    ⠼ 7879192fb664 Download complete                                        2.4s
#    ⠼ 4dc5b89c560e Download complete                                        2.4s
#    ⠼ bb8547bce572 Download complete                                        2.4s
#    ⠼ d71939ab0198 Download complete                                        2.4s
#  ⠇ postgres Pulling                                                        3.9s
#    ⠋ 1cb79db8a9e7 Extracting  14.68MB/22.53MB                              2.0s
#    ⠋ f6bae7873dd7 Download complete                                        2.0s
#    ⠋ 8f7722dc50a7 Download complete                                        2.0s
#    ⠋ e8622b8cb6f3 Waiting                                                  2.0s
#    ⠋ d6d74bba3a57 Waiting                                                  2.0s
#    ⠋ 874d4d2a09fd Waiting                                                  2.0s
#    ⠋ 2d87c3a4038c Waiting                                                  2.0s
#    ⠋ f955a6cf127b Waiting                                                  2.0s
# ...
#  => => extracting sha256:c4401b8c7f9e459a19eeaabd706ebb31c186a79e3aebf3ce  0.1s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         lib  86.9s
#  => [3/6] COPY script/entrypoint.sh /entrypoint.sh                         0.0s
#  => [4/6] COPY config/airflow.cfg /usr/local/airflow/airflow.cfg           0.0s
#  => [5/6] RUN chown -R airflow: /usr/local/airflow                         0.5s
#  => [6/6] WORKDIR /usr/local/airflow                                       0.0s
#  => exporting to image                                                     6.9s
#  => => exporting layers                                                    6.9s
# [+] Building 101.9s (8/9)
#  => [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc27956e6a55f  5.3s
#  => => resolve docker.io/library/python:3.6-slim@sha256:2cfebc27956e6a55f  0.0s
#  => => sha256:2cfebc27956e6a55f78606864d91fe527696f9e32a7 1.86kB / 1.86kB  0.0s
#  => => sha256:28028f6c3ce569a6405909ca76e85469fbb85c9ee93 1.37kB / 1.37kB  0.0s
#  => => sha256:c1e40b69532f47ed3e92fabda2e711725befc34f118 8.54kB / 8.54kB  0.0s
#  => => sha256:a2abf6c4d29d43a4bf9fbb769f524d0fb36a2edab 31.36MB / 31.36MB  3.9s
#  => => sha256:625294dad115cba7d8e323b53306f6daaa85d021e1e 1.08MB / 1.08MB  0.3s
#  => => sha256:838e3a5a04bfd2abf562bafe0dddb30d987cd9fd4c3 9.74MB / 9.74MB  0.4s
#  => => sha256:e93b4e59b6895b037b9248ef23a300776f9bb80eb0425c9 235B / 235B  0.4s
#  => => sha256:c4401b8c7f9e459a19eeaabd706ebb31c186a79e3ae 2.50MB / 2.50MB  0.5s
#  => => extracting sha256:a2abf6c4d29d43a4bf9fbb769f524d0fb36a2edab49819c1  0.7s
#  => => extracting sha256:625294dad115cba7d8e323b53306f6daaa85d021e1e19c78  0.1s
#  => => extracting sha256:838e3a5a04bfd2abf562bafe0dddb30d987cd9fd4c3a666a  0.2s
#  => => extracting sha256:e93b4e59b6895b037b9248ef23a300776f9bb80eb0425c99  0.0s
#  => => extracting sha256:c4401b8c7f9e459a19eeaabd706ebb31c186a79e3aebf3ce  0.1s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         lib  86.9s
#  => [3/6] COPY script/entrypoint.sh /entrypoint.sh                         0.0s
#  => [4/6] COPY config/airflow.cfg /usr/local/airflow/airflow.cfg           0.0s
#  => [5/6] RUN chown -R airflow: /usr/local/airflow                         0.5s
#  => [6/6] WORKDIR /usr/local/airflow                                       0.0s
#  => exporting to image                                                     7.0s
#  => => exporting layers                                                    7.0s
# [+] Building 102.1s (8/9)
#  => [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc27956e6a55f  5.3s
#  => => resolve docker.io/library/python:3.6-slim@sha256:2cfebc27956e6a55f  0.0s
#  => => sha256:2cfebc27956e6a55f78606864d91fe527696f9e32a7 1.86kB / 1.86kB  0.0s
#  => => sha256:28028f6c3ce569a6405909ca76e85469fbb85c9ee93 1.37kB / 1.37kB  0.0s
#  => => sha256:c1e40b69532f47ed3e92fabda2e711725befc34f118 8.54kB / 8.54kB  0.0s
#  => => sha256:a2abf6c4d29d43a4bf9fbb769f524d0fb36a2edab 31.36MB / 31.36MB  3.9s
#  => => sha256:625294dad115cba7d8e323b53306f6daaa85d021e1e 1.08MB / 1.08MB  0.3s
#  => => sha256:838e3a5a04bfd2abf562bafe0dddb30d987cd9fd4c3 9.74MB / 9.74MB  0.4s
#  => => sha256:e93b4e59b6895b037b9248ef23a300776f9bb80eb0425c9 235B / 235B  0.4s
#  => => sha256:c4401b8c7f9e459a19eeaabd706ebb31c186a79e3ae 2.50MB / 2.50MB  0.5s
#  => => extracting sha256:a2abf6c4d29d43a4bf9fbb769f524d0fb36a2edab49819c1  0.7s
#  => => extracting sha256:625294dad115cba7d8e323b53306f6daaa85d021e1e19c78  0.1s
#  => => extracting sha256:838e3a5a04bfd2abf562bafe0dddb30d987cd9fd4c3a666a  0.2s
#  => => extracting sha256:e93b4e59b6895b037b9248ef23a300776f9bb80eb0425c99  0.0s
#  => => extracting sha256:c4401b8c7f9e459a19eeaabd706ebb31c186a79e3aebf3ce  0.1s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         lib  86.9s
#  => [3/6] COPY script/entrypoint.sh /entrypoint.sh                         0.0s
#  => [4/6] COPY config/airflow.cfg /usr/local/airflow/airflow.cfg           0.0s
#  => [5/6] RUN chown -R airflow: /usr/local/airflow                         0.5s
#  => [6/6] WORKDIR /usr/local/airflow                                       0.0s
#  => exporting to image                                                     7.2s
#  => => exporting layers                                                    7.2s
# [+] Building 102.2s (8/9)
#  => [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc27956e6a55f  5.3s
#  => => resolve docker.io/library/python:3.6-slim@sha256:2cfebc27956e6a55f  0.0s
#  => => sha256:2cfebc27956e6a55f78606864d91fe527696f9e32a7 1.86kB / 1.86kB  0.0s
#  => => sha256:28028f6c3ce569a6405909ca76e85469fbb85c9ee93 1.37kB / 1.37kB  0.0s
#  => => sha256:c1e40b69532f47ed3e92fabda2e711725befc34f118 8.54kB / 8.54kB  0.0s
#  => => sha256:a2abf6c4d29d43a4bf9fbb769f524d0fb36a2edab 31.36MB / 31.36MB  3.9s
#  => => sha256:625294dad115cba7d8e323b53306f6daaa85d021e1e 1.08MB / 1.08MB  0.3s
#  => => sha256:838e3a5a04bfd2abf562bafe0dddb30d987cd9fd4c3 9.74MB / 9.74MB  0.4s
#  => => sha256:e93b4e59b6895b037b9248ef23a300776f9bb80eb0425c9 235B / 235B  0.4s
#  => => sha256:c4401b8c7f9e459a19eeaabd706ebb31c186a79e3ae 2.50MB / 2.50MB  0.5s
#  => => extracting sha256:a2abf6c4d29d43a4bf9fbb769f524d0fb36a2edab49819c1  0.7s
#  => => extracting sha256:625294dad115cba7d8e323b53306f6daaa85d021e1e19c78  0.1s
#  => => extracting sha256:838e3a5a04bfd2abf562bafe0dddb30d987cd9fd4c3a666a  0.2s
#  => => extracting sha256:e93b4e59b6895b037b9248ef23a300776f9bb80eb0425c99  0.0s
#  => => extracting sha256:c4401b8c7f9e459a19eeaabd706ebb31c186a79e3aebf3ce  0.1s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         lib  86.9s
#  => [3/6] COPY script/entrypoint.sh /entrypoint.sh                         0.0s
#  => [4/6] COPY config/airflow.cfg /usr/local/airflow/airflow.cfg           0.0s
#  => [5/6] RUN chown -R airflow: /usr/local/airflow                         0.5s
#  => [6/6] WORKDIR /usr/local/airflow                                       0.0s
#  => exporting to image                                                     7.3s
#  => => exporting layers                                                    7.3s
# [+] Building 102.4s (8/9)
#  => [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc27956e6a55f  5.3s
#  => => resolve docker.io/library/python:3.6-slim@sha256:2cfebc27956e6a55f  0.0s
#  => => sha256:2cfebc27956e6a55f78606864d91fe527696f9e32a7 1.86kB / 1.86kB  0.0s
#  => => sha256:28028f6c3ce569a6405909ca76e85469fbb85c9ee93 1.37kB / 1.37kB  0.0s
#  => => sha256:c1e40b69532f47ed3e92fabda2e711725befc34f118 8.54kB / 8.54kB  0.0s
#  => => sha256:a2abf6c4d29d43a4bf9fbb769f524d0fb36a2edab 31.36MB / 31.36MB  3.9s
#  => => sha256:625294dad115cba7d8e323b53306f6daaa85d021e1e 1.08MB / 1.08MB  0.3s
#  => => sha256:838e3a5a04bfd2abf562bafe0dddb30d987cd9fd4c3 9.74MB / 9.74MB  0.4s
#  => => sha256:e93b4e59b6895b037b9248ef23a300776f9bb80eb0425c9 235B / 235B  0.4s
#  => => sha256:c4401b8c7f9e459a19eeaabd706ebb31c186a79e3ae 2.50MB / 2.50MB  0.5s
#  => => extracting sha256:a2abf6c4d29d43a4bf9fbb769f524d0fb36a2edab49819c1  0.7s
#  => => extracting sha256:625294dad115cba7d8e323b53306f6daaa85d021e1e19c78  0.1s
#  => => extracting sha256:838e3a5a04bfd2abf562bafe0dddb30d987cd9fd4c3a666a  0.2s
#  => => extracting sha256:e93b4e59b6895b037b9248ef23a300776f9bb80eb0425c99  0.0s
#  => => extracting sha256:c4401b8c7f9e459a19eeaabd706ebb31c186a79e3aebf3ce  0.1s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         lib  86.9s
#  => [3/6] COPY script/entrypoint.sh /entrypoint.sh                         0.0s
#  => [4/6] COPY config/airflow.cfg /usr/local/airflow/airflow.cfg           0.0s
#  => [5/6] RUN chown -R airflow: /usr/local/airflow                         0.5s
#  => [6/6] WORKDIR /usr/local/airflow                                       0.0s
#  => exporting to image                                                     7.5s
#  => => exporting layers                                                    7.5s
# [+] Building 102.5s (8/9)
#  => [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc27956e6a55f  5.3s
#  => => resolve docker.io/library/python:3.6-slim@sha256:2cfebc27956e6a55f  0.0s
#  => => sha256:2cfebc27956e6a55f78606864d91fe527696f9e32a7 1.86kB / 1.86kB  0.0s
#  => => sha256:28028f6c3ce569a6405909ca76e85469fbb85c9ee93 1.37kB / 1.37kB  0.0s
#  => => sha256:c1e40b69532f47ed3e92fabda2e711725befc34f118 8.54kB / 8.54kB  0.0s
#  => => sha256:a2abf6c4d29d43a4bf9fbb769f524d0fb36a2edab 31.36MB / 31.36MB  3.9s
#  => => sha256:625294dad115cba7d8e323b53306f6daaa85d021e1e 1.08MB / 1.08MB  0.3s
#  => => sha256:838e3a5a04bfd2abf562bafe0dddb30d987cd9fd4c3 9.74MB / 9.74MB  0.4s
#  => => sha256:e93b4e59b6895b037b9248ef23a300776f9bb80eb0425c9 235B / 235B  0.4s
#  => => sha256:c4401b8c7f9e459a19eeaabd706ebb31c186a79e3ae 2.50MB / 2.50MB  0.5s
#  => => extracting sha256:a2abf6c4d29d43a4bf9fbb769f524d0fb36a2edab49819c1  0.7s
#  => => extracting sha256:625294dad115cba7d8e323b53306f6daaa85d021e1e19c78  0.1s
#  => => extracting sha256:838e3a5a04bfd2abf562bafe0dddb30d987cd9fd4c3a666a  0.2s
#  => => extracting sha256:e93b4e59b6895b037b9248ef23a300776f9bb80eb0425c99  0.0s
#  => => extracting sha256:c4401b8c7f9e459a19eeaabd706ebb31c186a79e3aebf3ce  0.1s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         lib  86.9s
#  => [3/6] COPY script/entrypoint.sh /entrypoint.sh                         0.0s
#  => [4/6] COPY config/airflow.cfg /usr/local/airflow/airflow.cfg           0.0s
#  => [5/6] RUN chown -R airflow: /usr/local/airflow                         0.5s
#  => [6/6] WORKDIR /usr/local/airflow                                       0.0s
#  => exporting to image                                                     7.6s
#  => => exporting layers                                                    7.6s
# [+] Building 102.7s (8/9)
#  => [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc27956e6a55f  5.3s
#  => => resolve docker.io/library/python:3.6-slim@sha256:2cfebc27956e6a55f  0.0s
#  => => sha256:2cfebc27956e6a55f78606864d91fe527696f9e32a7 1.86kB / 1.86kB  0.0s
#  => => sha256:28028f6c3ce569a6405909ca76e85469fbb85c9ee93 1.37kB / 1.37kB  0.0s
#  => => sha256:c1e40b69532f47ed3e92fabda2e711725befc34f118 8.54kB / 8.54kB  0.0s
#  => => sha256:a2abf6c4d29d43a4bf9fbb769f524d0fb36a2edab 31.36MB / 31.36MB  3.9s
#  => => sha256:625294dad115cba7d8e323b53306f6daaa85d021e1e 1.08MB / 1.08MB  0.3s
#  => => sha256:838e3a5a04bfd2abf562bafe0dddb30d987cd9fd4c3 9.74MB / 9.74MB  0.4s
#  => => sha256:e93b4e59b6895b037b9248ef23a300776f9bb80eb0425c9 235B / 235B  0.4s
#  => => sha256:c4401b8c7f9e459a19eeaabd706ebb31c186a79e3ae 2.50MB / 2.50MB  0.5s
#  => => extracting sha256:a2abf6c4d29d43a4bf9fbb769f524d0fb36a2edab49819c1  0.7s
#  => => extracting sha256:625294dad115cba7d8e323b53306f6daaa85d021e1e19c78  0.1s
#  => => extracting sha256:838e3a5a04bfd2abf562bafe0dddb30d987cd9fd4c3a666a  0.2s
#  => => extracting sha256:e93b4e59b6895b037b9248ef23a300776f9bb80eb0425c99  0.0s
#  => => extracting sha256:c4401b8c7f9e459a19eeaabd706ebb31c186a79e3aebf3ce  0.1s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         lib  86.9s
#  => [3/6] COPY script/entrypoint.sh /entrypoint.sh                         0.0s
#  => [4/6] COPY config/airflow.cfg /usr/local/airflow/airflow.cfg           0.0s
#  => [5/6] RUN chown -R airflow: /usr/local/airflow                         0.5s
#  => [6/6] WORKDIR /usr/local/airflow                                       0.0s
#  => exporting to image                                                     7.7s
#  => => exporting layers                                                    7.7s
# [+] Building 102.7s (9/9) FINISHED
#  => [internal] load git source https://github.com/puckel/docker-airflow.g  0.8s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         1.2s
#  => [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc27956e6a55f  5.3s
#  => => resolve docker.io/library/python:3.6-slim@sha256:2cfebc27956e6a55f  0.0s
#  => => sha256:2cfebc27956e6a55f78606864d91fe527696f9e32a7 1.86kB / 1.86kB  0.0s
#  => => sha256:28028f6c3ce569a6405909ca76e85469fbb85c9ee93 1.37kB / 1.37kB  0.0s
#  => => sha256:c1e40b69532f47ed3e92fabda2e711725befc34f118 8.54kB / 8.54kB  0.0s
#  => => sha256:a2abf6c4d29d43a4bf9fbb769f524d0fb36a2edab 31.36MB / 31.36MB  3.9s
#  => => sha256:625294dad115cba7d8e323b53306f6daaa85d021e1e 1.08MB / 1.08MB  0.3s
#  => => sha256:838e3a5a04bfd2abf562bafe0dddb30d987cd9fd4c3 9.74MB / 9.74MB  0.4s
#  => => sha256:e93b4e59b6895b037b9248ef23a300776f9bb80eb0425c9 235B / 235B  0.4s
#  => => sha256:c4401b8c7f9e459a19eeaabd706ebb31c186a79e3ae 2.50MB / 2.50MB  0.5s
#  => => extracting sha256:a2abf6c4d29d43a4bf9fbb769f524d0fb36a2edab49819c1  0.7s
#  => => extracting sha256:625294dad115cba7d8e323b53306f6daaa85d021e1e19c78  0.1s
#  => => extracting sha256:838e3a5a04bfd2abf562bafe0dddb30d987cd9fd4c3a666a  0.2s
#  => => extracting sha256:e93b4e59b6895b037b9248ef23a300776f9bb80eb0425c99  0.0s
#  => => extracting sha256:c4401b8c7f9e459a19eeaabd706ebb31c186a79e3aebf3ce  0.1s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         lib  86.9s
#  => [3/6] COPY script/entrypoint.sh /entrypoint.sh                         0.0s
#  => [4/6] COPY config/airflow.cfg /usr/local/airflow/airflow.cfg           0.0s
#  => [5/6] RUN chown -R airflow: /usr/local/airflow                         0.5s
#  => [6/6] WORKDIR /usr/local/airflow                                       0.0s
#  => exporting to image                                                     7.7s
#  => => exporting layers                                                    7.7s
#  => => writing image sha256:ffe8365fc575c39ad30318f81ae6c294dbaaa752146e5  0.0s
#  => => naming to docker.io/puckel/docker-airflow:1.10.1                    0.0s
#
# Use 'docker scan' to run Snyk tests against images to find vulnerabilities and learn how to fix them
# [+] Running 2/0
#  ⠿ Network airflow-tutorial_default        Created                         0.0s
#  ⠿ Container airflow-tutorial-postgres-1   Starting                        0.1s
#  ⠿ Container airflow-tutorial-webserver-1  Created                         0.0s
# [+] Running 2/3
#  ⠿ Network airflow-tutorial_default        Created                         0.0s
#  ⠿ Container airflow-tutorial-postgres-1   Starting                        0.2s
#  ⠿ Container airflow-tutorial-webserver-1  Created                         0.0s
# [+] Running 2/3
#  ⠿ Network airflow-tutorial_default        Created                         0.0s
#  ⠿ Container airflow-tutorial-postgres-1   Starting                        0.3s
#  ⠿ Container airflow-tutorial-webserver-1  Created                         0.0s
# [+] Running 2/3
#  ⠿ Network airflow-tutorial_default        Created                         0.0s
#  ⠿ Container airflow-tutorial-postgres-1   Starting                        0.4s
#  ⠿ Container airflow-tutorial-webserver-1  Created                         0.0s
# [+] Running 2/3
#  ⠿ Network airflow-tutorial_default        Created                         0.0s
#  ⠿ Container airflow-tutorial-postgres-1   Started                         0.4s
#  ⠿ Container airflow-tutorial-webserver-1  Starting                        0.4s
# [+] Running 2/3
#  ⠿ Network airflow-tutorial_default        Created                         0.0s
#  ⠿ Container airflow-tutorial-postgres-1   Started                         0.4s
#  ⠿ Container airflow-tutorial-webserver-1  Starting                        0.5s
# [+] Running 2/3
#  ⠿ Network airflow-tutorial_default        Created                         0.0s
#  ⠿ Container airflow-tutorial-postgres-1   Started                         0.4s
#  ⠿ Container airflow-tutorial-webserver-1  Starting                        0.6s
# [+] Running 3/3
#  ⠿ Network airflow-tutorial_default        Created                         0.0s
#  ⠿ Container airflow-tutorial-postgres-1   Started                         0.4s
#  ⠿ Container airflow-tutorial-webserver-1  Started                         0.7s

# %%
# !docker-compose up -d
# Out:
# [+] Running 0/0
#  ⠋ Container airflow-tutorial-postgres-1  Recreate                         0.1s
# [+] Running 0/1
#  ⠙ Container airflow-tutorial-postgres-1  Recreate                         0.2s
# [+] Running 1/1
#  ⠿ Container airflow-tutorial-postgres-1   Starting                        0.3s
#  ⠿ Container airflow-tutorial-webserver-1  Recreated                       0.0s
# [+] Running 1/2
#  ⠿ Container airflow-tutorial-postgres-1   Starting                        0.4s
#  ⠿ Container airflow-tutorial-webserver-1  Recreated                       0.0s
# [+] Running 1/2
#  ⠿ Container airflow-tutorial-postgres-1   Starting                        0.5s
#  ⠿ Container airflow-tutorial-webserver-1  Recreated                       0.0s
# [+] Running 2/2
#  ⠿ Container airflow-tutorial-postgres-1   Started                         0.6s
#  ⠿ Container airflow-tutorial-webserver-1  Recreated                       0.0s
# [+] Running 1/2
#  ⠿ Container airflow-tutorial-postgres-1   Started                         0.6s
#  ⠿ Container airflow-tutorial-webserver-1  Starting                        0.4s
# [+] Running 1/2
#  ⠿ Container airflow-tutorial-postgres-1   Started                         0.6s
#  ⠿ Container airflow-tutorial-webserver-1  Starting                        0.5s
# [+] Running 1/2
#  ⠿ Container airflow-tutorial-postgres-1   Started                         0.6s
#  ⠿ Container airflow-tutorial-webserver-1  Starting                        0.6s
# [+] Running 2/2
#  ⠿ Container airflow-tutorial-postgres-1   Started                         0.6s
#  ⠿ Container airflow-tutorial-webserver-1  Started                         0.7s

# %%
# !docker-compose up -d --build
# Out:
# [+] Building 0.0s (0/0)
# [+] Building 0.0s (0/0)
# [+] Building 0.0s (0/0)
# [+] Building 0.0s (0/0)
# [+] Building 0.0s (0/0)
# [+] Building 0.0s (0/0)
# [+] Building 0.0s (0/0)
# [+] Building 0.0s (0/1)
# [+] Building 0.2s (0/1)
#  => [internal] load git source https://github.com/puckel/docker-airflow.g  0.2s
# [+] Building 0.3s (0/1)
#  => [internal] load git source https://github.com/puckel/docker-airflow.g  0.3s
# [+] Building 0.5s (1/1)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
# [+] Building 0.6s (1/2)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.1s
# [+] Building 0.8s (1/2)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.2s
# [+] Building 0.9s (1/2)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.4s
# [+] Building 1.1s (1/2)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.5s
# [+] Building 1.2s (1/2)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.7s
# [+] Building 1.4s (1/2)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
# [+] Building 1.5s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  0.1s
# [+] Building 1.7s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  0.3s
#  => => # + buildDeps=         freetds-dev         libkrb5-dev         libsasl2-
#  => => # dev         libssl-dev         libffi-dev         libpq-dev         gi
#  => => # t
#  => => # + apt-get update -yqq
# [+] Building 1.8s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  0.4s
#  => => # + buildDeps=         freetds-dev         libkrb5-dev         libsasl2-
#  => => # dev         libssl-dev         libffi-dev         libpq-dev         gi
#  => => # t
#  => => # + apt-get update -yqq
# [+] Building 2.0s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  0.6s
#  => => # + buildDeps=         freetds-dev         libkrb5-dev         libsasl2-
#  => => # dev         libssl-dev         libffi-dev         libpq-dev         gi
#  => => # t
#  => => # + apt-get update -yqq
# [+] Building 2.1s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  0.7s
#  => => # + buildDeps=         freetds-dev         libkrb5-dev         libsasl2-
#  => => # dev         libssl-dev         libffi-dev         libpq-dev         gi
#  => => # t
#  => => # + apt-get update -yqq
# [+] Building 2.3s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  0.9s
#  => => # + buildDeps=         freetds-dev         libkrb5-dev         libsasl2-
#  => => # dev         libssl-dev         libffi-dev         libpq-dev         gi
#  => => # t
#  => => # + apt-get update -yqq
# [+] Building 2.4s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  1.0s
#  => => # + buildDeps=         freetds-dev         libkrb5-dev         libsasl2-
#  => => # dev         libssl-dev         libffi-dev         libpq-dev         gi
#  => => # t
#  => => # + apt-get update -yqq
# [+] Building 2.6s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  1.2s
#  => => # + buildDeps=         freetds-dev         libkrb5-dev         libsasl2-
#  => => # dev         libssl-dev         libffi-dev         libpq-dev         gi
#  => => # t
#  => => # + apt-get update -yqq
# [+] Building 2.7s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  1.3s
#  => => # + buildDeps=         freetds-dev         libkrb5-dev         libsasl2-
#  => => # dev         libssl-dev         libffi-dev         libpq-dev         gi
#  => => # t
#  => => # + apt-get update -yqq
# [+] Building 2.9s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  1.5s
#  => => # + buildDeps=         freetds-dev         libkrb5-dev         libsasl2-
#  => => # dev         libssl-dev         libffi-dev         libpq-dev         gi
#  => => # t
#  => => # + apt-get update -yqq
# [+] Building 3.0s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  1.6s
#  => => # + buildDeps=         freetds-dev         libkrb5-dev         libsasl2-
#  => => # dev         libssl-dev         libffi-dev         libpq-dev         gi
#  => => # t
#  => => # + apt-get update -yqq
# [+] Building 3.2s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  1.8s
#  => => # + buildDeps=         freetds-dev         libkrb5-dev         libsasl2-
#  => => # dev         libssl-dev         libffi-dev         libpq-dev         gi
#  => => # t
#  => => # + apt-get update -yqq
#  => => # + apt-get upgrade -yqq
# [+] Building 3.3s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  1.9s
#  => => # + buildDeps=         freetds-dev         libkrb5-dev         libsasl2-
#  => => # dev         libssl-dev         libffi-dev         libpq-dev         gi
#  => => # t
#  => => # + apt-get update -yqq
#  => => # + apt-get upgrade -yqq
# [+] Building 3.5s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  2.1s
#  => => # + buildDeps=         freetds-dev         libkrb5-dev         libsasl2-
#  => => # dev         libssl-dev         libffi-dev         libpq-dev         gi
#  => => # t
#  => => # + apt-get update -yqq
#  => => # + apt-get upgrade -yqq
# [+] Building 3.6s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  2.2s
#  => => # + buildDeps=         freetds-dev         libkrb5-dev         libsasl2-
#  => => # dev         libssl-dev         libffi-dev         libpq-dev         gi
#  => => # t
#  => => # + apt-get update -yqq
#  => => # + apt-get upgrade -yqq
# [+] Building 3.8s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  2.4s
#  => => # + buildDeps=         freetds-dev         libkrb5-dev         libsasl2-
#  => => # dev         libssl-dev         libffi-dev         libpq-dev         gi
#  => => # t
#  => => # + apt-get update -yqq
#  => => # + apt-get upgrade -yqq
# [+] Building 3.9s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  2.5s
#  => => # LC_ALL = "en_US.UTF-8",
#  => => # LC_CTYPE = "en_US.UTF-8",
#  => => # LC_MESSAGES = "en_US.UTF-8",
#  => => # LANG = "en_US.UTF-8"
#  => => #     are supported and installed on your system.
#  => => # perl: warning: Falling back to the standard locale ("C").
# [+] Building 4.0s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  2.7s
#  => => # debconf: delaying package configuration, since apt-utils is not instal
#  => => # led
#  => => # (Reading database ... 7023 files and directories currently installed.)
#  => => # Preparing to unpack .../base-files_11.1+deb11u3_amd64.deb ...
#  => => # Unpacking base-files (11.1+deb11u3) over (11.1+deb11u2) ...
#  => => # Setting up base-files (11.1+deb11u3) ...
# [+] Building 4.2s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  2.8s
#  => => # Preparing to unpack .../bsdutils_1%3a2.36.1-8+deb11u1_amd64.deb ...
#  => => # Unpacking bsdutils (1:2.36.1-8+deb11u1) over (1:2.36.1-8) ...
#  => => # Setting up bsdutils (1:2.36.1-8+deb11u1) ...
#  => => # (Reading database ... 7023 files and directories currently installed.)
#  => => # Preparing to unpack .../dpkg_1.20.10_amd64.deb ...
#  => => # Unpacking dpkg (1.20.10) over (1.20.9) ...
# [+] Building 4.3s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  2.9s
#  => => # Unpacking dpkg (1.20.10) over (1.20.9) ...
#  => => # Setting up dpkg (1.20.10) ...
#  => => # (Reading database ... 7032 files and directories currently installed.)
#  => => # Preparing to unpack .../gzip_1.10-4+deb11u1_amd64.deb ...
#  => => # Unpacking gzip (1.10-4+deb11u1) over (1.10-4) ...
#  => => # Setting up gzip (1.10-4+deb11u1) ...
# [+] Building 4.4s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  3.1s
#  => => # Preparing to unpack .../gzip_1.10-4+deb11u1_amd64.deb ...
#  => => # Unpacking gzip (1.10-4+deb11u1) over (1.10-4) ...
#  => => # Setting up gzip (1.10-4+deb11u1) ...
#  => => # (Reading database ... 7032 files and directories currently installed.)
#  => => # Preparing to unpack .../util-linux_2.36.1-8+deb11u1_amd64.deb ...
#  => => # Unpacking util-linux (2.36.1-8+deb11u1) over (2.36.1-8) ...
# [+] Building 4.6s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  3.2s
#  => => # Setting up util-linux (2.36.1-8+deb11u1) ...
#  => => # update-alternatives: warning: forcing reinstallation of alternative /b
#  => => # in/more because link group pager is broken
#  => => # update-alternatives: warning: skip creation of /usr/share/man/man1/pag
#  => => # er.1.gz because associated file /usr/share/man/man1/more.1.gz (of link
#  => => #  group pager) doesn't exist
# [+] Building 4.7s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  3.4s
#  => => # update-alternatives: warning: skip creation of /usr/share/man/man1/pag
#  => => # er.1.gz because associated file /usr/share/man/man1/more.1.gz (of link
#  => => #  group pager) doesn't exist
#  => => # (Reading database ... 7032 files and directories currently installed.)
#  => => # Preparing to unpack .../libc6_2.31-13+deb11u3_amd64.deb ...
#  => => # Unpacking libc6:amd64 (2.31-13+deb11u3) over (2.31-13+deb11u2) ...
# [+] Building 4.9s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  3.5s
#  => => # update-alternatives: warning: skip creation of /usr/share/man/man1/pag
#  => => # er.1.gz because associated file /usr/share/man/man1/more.1.gz (of link
#  => => #  group pager) doesn't exist
#  => => # (Reading database ... 7032 files and directories currently installed.)
#  => => # Preparing to unpack .../libc6_2.31-13+deb11u3_amd64.deb ...
#  => => # Unpacking libc6:amd64 (2.31-13+deb11u3) over (2.31-13+deb11u2) ...
# [+] Building 5.0s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  3.7s
#  => => # update-alternatives: warning: skip creation of /usr/share/man/man1/pag
#  => => # er.1.gz because associated file /usr/share/man/man1/more.1.gz (of link
#  => => #  group pager) doesn't exist
#  => => # (Reading database ... 7032 files and directories currently installed.)
#  => => # Preparing to unpack .../libc6_2.31-13+deb11u3_amd64.deb ...
#  => => # Unpacking libc6:amd64 (2.31-13+deb11u3) over (2.31-13+deb11u2) ...
# [+] Building 5.2s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  3.8s
#  => => # er.1.gz because associated file /usr/share/man/man1/more.1.gz (of link
#  => => #  group pager) doesn't exist
#  => => # (Reading database ... 7032 files and directories currently installed.)
#  => => # Preparing to unpack .../libc6_2.31-13+deb11u3_amd64.deb ...
#  => => # Unpacking libc6:amd64 (2.31-13+deb11u3) over (2.31-13+deb11u2) ...
#  => => # Setting up libc6:amd64 (2.31-13+deb11u3) ...
# [+] Building 5.3s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  4.0s
#  => => # er.1.gz because associated file /usr/share/man/man1/more.1.gz (of link
#  => => #  group pager) doesn't exist
#  => => # (Reading database ... 7032 files and directories currently installed.)
#  => => # Preparing to unpack .../libc6_2.31-13+deb11u3_amd64.deb ...
#  => => # Unpacking libc6:amd64 (2.31-13+deb11u3) over (2.31-13+deb11u2) ...
#  => => # Setting up libc6:amd64 (2.31-13+deb11u3) ...
# [+] Building 5.5s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  4.1s
#  => => # er.1.gz because associated file /usr/share/man/man1/more.1.gz (of link
#  => => #  group pager) doesn't exist
#  => => # (Reading database ... 7032 files and directories currently installed.)
#  => => # Preparing to unpack .../libc6_2.31-13+deb11u3_amd64.deb ...
#  => => # Unpacking libc6:amd64 (2.31-13+deb11u3) over (2.31-13+deb11u2) ...
#  => => # Setting up libc6:amd64 (2.31-13+deb11u3) ...
# [+] Building 5.6s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  4.3s
#  => => # er.1.gz because associated file /usr/share/man/man1/more.1.gz (of link
#  => => #  group pager) doesn't exist
#  => => # (Reading database ... 7032 files and directories currently installed.)
#  => => # Preparing to unpack .../libc6_2.31-13+deb11u3_amd64.deb ...
#  => => # Unpacking libc6:amd64 (2.31-13+deb11u3) over (2.31-13+deb11u2) ...
#  => => # Setting up libc6:amd64 (2.31-13+deb11u3) ...
# [+] Building 5.8s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  4.4s
#  => => # er.1.gz because associated file /usr/share/man/man1/more.1.gz (of link
#  => => #  group pager) doesn't exist
#  => => # (Reading database ... 7032 files and directories currently installed.)
#  => => # Preparing to unpack .../libc6_2.31-13+deb11u3_amd64.deb ...
#  => => # Unpacking libc6:amd64 (2.31-13+deb11u3) over (2.31-13+deb11u2) ...
#  => => # Setting up libc6:amd64 (2.31-13+deb11u3) ...
# [+] Building 5.9s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  4.6s
#  => => # er.1.gz because associated file /usr/share/man/man1/more.1.gz (of link
#  => => #  group pager) doesn't exist
#  => => # (Reading database ... 7032 files and directories currently installed.)
#  => => # Preparing to unpack .../libc6_2.31-13+deb11u3_amd64.deb ...
#  => => # Unpacking libc6:amd64 (2.31-13+deb11u3) over (2.31-13+deb11u2) ...
#  => => # Setting up libc6:amd64 (2.31-13+deb11u3) ...
# [+] Building 6.1s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  4.7s
#  => => # er.1.gz because associated file /usr/share/man/man1/more.1.gz (of link
#  => => #  group pager) doesn't exist
#  => => # (Reading database ... 7032 files and directories currently installed.)
#  => => # Preparing to unpack .../libc6_2.31-13+deb11u3_amd64.deb ...
#  => => # Unpacking libc6:amd64 (2.31-13+deb11u3) over (2.31-13+deb11u2) ...
#  => => # Setting up libc6:amd64 (2.31-13+deb11u3) ...
# [+] Building 6.3s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  4.9s
#  => => # Preparing to unpack .../libc6_2.31-13+deb11u3_amd64.deb ...
#  => => # Unpacking libc6:amd64 (2.31-13+deb11u3) over (2.31-13+deb11u2) ...
#  => => # Setting up libc6:amd64 (2.31-13+deb11u3) ...
#  => => # (Reading database ... 7032 files and directories currently installed.)
#  => => # Preparing to unpack .../libc-bin_2.31-13+deb11u3_amd64.deb ...
#  => => # Unpacking libc-bin (2.31-13+deb11u3) over (2.31-13+deb11u2) ...
# [+] Building 6.4s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  5.0s
#  => => # Setting up libc-bin (2.31-13+deb11u3) ...
#  => => # (Reading database ... 7032 files and directories currently installed.)
#  => => # Preparing to unpack .../sysvinit-utils_2.96-7+deb11u1_amd64.deb ...
#  => => # Unpacking sysvinit-utils (2.96-7+deb11u1) over (2.96-7) ...
#  => => # Setting up sysvinit-utils (2.96-7+deb11u1) ...
#  => => # (Reading database ...
# [+] Building 6.5s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  5.1s
#  => => # Preparing to unpack .../mount_2.36.1-8+deb11u1_amd64.deb ...
#  => => # Unpacking mount (2.36.1-8+deb11u1) over (2.36.1-8) ...
#  => => # Preparing to unpack .../zlib1g_1%3a1.2.11.dfsg-2+deb11u1_amd64.deb ...
#  => => # Unpacking zlib1g:amd64 (1:1.2.11.dfsg-2+deb11u1) over (1:1.2.11.dfsg-2
#  => => # ) ...
#  => => # Setting up zlib1g:amd64 (1:1.2.11.dfsg-2+deb11u1) ...
# [+] Building 6.6s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  5.2s
#  => => # Setting up gpgv (2.2.27-2+deb11u1) ...
#  => => # (Reading database ... 7032 files and directories currently installed.)
#  => => # Preparing to unpack .../libblkid1_2.36.1-8+deb11u1_amd64.deb ...
#  => => # Unpacking libblkid1:amd64 (2.36.1-8+deb11u1) over (2.36.1-8) ...
#  => => # Setting up libblkid1:amd64 (2.36.1-8+deb11u1) ...
#  => => # (Reading database ...
# [+] Building 6.7s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  5.3s
#  => => # Preparing to unpack .../libmount1_2.36.1-8+deb11u1_amd64.deb ...
#  => => # Unpacking libmount1:amd64 (2.36.1-8+deb11u1) over (2.36.1-8) ...
#  => => # Setting up libmount1:amd64 (2.36.1-8+deb11u1) ...
#  => => # (Reading database ... 7032 files and directories currently installed.)
#  => => # Preparing to unpack .../libsmartcols1_2.36.1-8+deb11u1_amd64.deb ...
#  => => # Unpacking libsmartcols1:amd64 (2.36.1-8+deb11u1) over (2.36.1-8) ...
# [+] Building 6.8s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  5.4s
#  => => # Setting up libsmartcols1:amd64 (2.36.1-8+deb11u1) ...
#  => => # (Reading database ... 7032 files and directories currently installed.)
#  => => # Preparing to unpack .../libssl1.1_1.1.1n-0+deb11u2_amd64.deb ...
#  => => # Unpacking libssl1.1:amd64 (1.1.1n-0+deb11u2) over (1.1.1k-1+deb11u1) .
#  => => # ..
#  => => # Setting up libssl1.1:amd64 (1.1.1n-0+deb11u2) ...
# [+] Building 6.9s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  5.5s
#  => => # Setting up libssl1.1:amd64 (1.1.1n-0+deb11u2) ...
#  => => # (Reading database ... 7032 files and directories currently installed.)
#  => => # Preparing to unpack .../libudev1_247.3-7_amd64.deb ...
#  => => # Unpacking libudev1:amd64 (247.3-7) over (247.3-6) ...
#  => => # Setting up libudev1:amd64 (247.3-7) ...
#  => => # (Reading database ...
# [+] Building 7.1s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  5.7s
#  => => # Preparing to unpack .../libuuid1_2.36.1-8+deb11u1_amd64.deb ...
#  => => # Unpacking libuuid1:amd64 (2.36.1-8+deb11u1) over (2.36.1-8) ...
#  => => # Setting up libuuid1:amd64 (2.36.1-8+deb11u1) ...
#  => => # (Reading database ... 7032 files and directories currently installed.)
#  => => # Preparing to unpack .../tzdata_2021a-1+deb11u3_all.deb ...
#  => => # Unpacking tzdata (2021a-1+deb11u3) over (2021a-1+deb11u2) ...
# [+] Building 7.2s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  5.8s
#  => => # Preparing to unpack .../libuuid1_2.36.1-8+deb11u1_amd64.deb ...
#  => => # Unpacking libuuid1:amd64 (2.36.1-8+deb11u1) over (2.36.1-8) ...
#  => => # Setting up libuuid1:amd64 (2.36.1-8+deb11u1) ...
#  => => # (Reading database ... 7032 files and directories currently installed.)
#  => => # Preparing to unpack .../tzdata_2021a-1+deb11u3_all.deb ...
#  => => # Unpacking tzdata (2021a-1+deb11u3) over (2021a-1+deb11u2) ...
# [+] Building 7.4s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  6.0s
#  => => # Preparing to unpack .../libuuid1_2.36.1-8+deb11u1_amd64.deb ...
#  => => # Unpacking libuuid1:amd64 (2.36.1-8+deb11u1) over (2.36.1-8) ...
#  => => # Setting up libuuid1:amd64 (2.36.1-8+deb11u1) ...
#  => => # (Reading database ... 7032 files and directories currently installed.)
#  => => # Preparing to unpack .../tzdata_2021a-1+deb11u3_all.deb ...
#  => => # Unpacking tzdata (2021a-1+deb11u3) over (2021a-1+deb11u2) ...
# [+] Building 7.5s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  6.2s
#  => => # Preparing to unpack .../libuuid1_2.36.1-8+deb11u1_amd64.deb ...
#  => => # Unpacking libuuid1:amd64 (2.36.1-8+deb11u1) over (2.36.1-8) ...
#  => => # Setting up libuuid1:amd64 (2.36.1-8+deb11u1) ...
#  => => # (Reading database ... 7032 files and directories currently installed.)
#  => => # Preparing to unpack .../tzdata_2021a-1+deb11u3_all.deb ...
#  => => # Unpacking tzdata (2021a-1+deb11u3) over (2021a-1+deb11u2) ...
# [+] Building 7.7s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  6.3s
#  => => # Preparing to unpack .../libuuid1_2.36.1-8+deb11u1_amd64.deb ...
#  => => # Unpacking libuuid1:amd64 (2.36.1-8+deb11u1) over (2.36.1-8) ...
#  => => # Setting up libuuid1:amd64 (2.36.1-8+deb11u1) ...
#  => => # (Reading database ... 7032 files and directories currently installed.)
#  => => # Preparing to unpack .../tzdata_2021a-1+deb11u3_all.deb ...
#  => => # Unpacking tzdata (2021a-1+deb11u3) over (2021a-1+deb11u2) ...
# [+] Building 7.8s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  6.5s
#  => => # Preparing to unpack .../libuuid1_2.36.1-8+deb11u1_amd64.deb ...
#  => => # Unpacking libuuid1:amd64 (2.36.1-8+deb11u1) over (2.36.1-8) ...
#  => => # Setting up libuuid1:amd64 (2.36.1-8+deb11u1) ...
#  => => # (Reading database ... 7032 files and directories currently installed.)
#  => => # Preparing to unpack .../tzdata_2021a-1+deb11u3_all.deb ...
#  => => # Unpacking tzdata (2021a-1+deb11u3) over (2021a-1+deb11u2) ...
# [+] Building 8.0s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  6.6s
#  => => # Unpacking tzdata (2021a-1+deb11u3) over (2021a-1+deb11u2) ...
#  => => # Preparing to unpack .../libexpat1_2.2.10-2+deb11u3_amd64.deb ...
#  => => # Unpacking libexpat1:amd64 (2.2.10-2+deb11u3) over (2.2.10-2) ...
#  => => # Preparing to unpack .../openssl_1.1.1n-0+deb11u2_amd64.deb ...
#  => => # Unpacking openssl (1.1.1n-0+deb11u2) over (1.1.1k-1+deb11u1) ...
#  => => # Setting up libexpat1:amd64 (2.2.10-2+deb11u3) ...
# [+] Building 8.1s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  6.7s
#  => => # Setting up mount (2.36.1-8+deb11u1) ...
#  => => # Setting up openssl (1.1.1n-0+deb11u2) ...
#  => => # Processing triggers for libc-bin (2.31-13+deb11u3) ...
#  => => # + apt-get install -yqq --no-install-recommends freetds-dev libkrb5-dev
#  => => #  libsasl2-dev libssl-dev libffi-dev libpq-dev git freetds-bin build-es
#  => => # sential default-libmysqlclient-dev apt-utils curl rsync netcat locales
# [+] Building 8.2s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  6.8s
#  => => # Setting up mount (2.36.1-8+deb11u1) ...
#  => => # Setting up openssl (1.1.1n-0+deb11u2) ...
#  => => # Processing triggers for libc-bin (2.31-13+deb11u3) ...
#  => => # + apt-get install -yqq --no-install-recommends freetds-dev libkrb5-dev
#  => => #  libsasl2-dev libssl-dev libffi-dev libpq-dev git freetds-bin build-es
#  => => # sential default-libmysqlclient-dev apt-utils curl rsync netcat locales
# [+] Building 8.4s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  7.0s
#  => => # Setting up mount (2.36.1-8+deb11u1) ...
#  => => # Setting up openssl (1.1.1n-0+deb11u2) ...
#  => => # Processing triggers for libc-bin (2.31-13+deb11u3) ...
#  => => # + apt-get install -yqq --no-install-recommends freetds-dev libkrb5-dev
#  => => #  libsasl2-dev libssl-dev libffi-dev libpq-dev git freetds-bin build-es
#  => => # sential default-libmysqlclient-dev apt-utils curl rsync netcat locales
# [+] Building 8.5s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  7.2s
#  => => # Setting up mount (2.36.1-8+deb11u1) ...
#  => => # Setting up openssl (1.1.1n-0+deb11u2) ...
#  => => # Processing triggers for libc-bin (2.31-13+deb11u3) ...
#  => => # + apt-get install -yqq --no-install-recommends freetds-dev libkrb5-dev
#  => => #  libsasl2-dev libssl-dev libffi-dev libpq-dev git freetds-bin build-es
#  => => # sential default-libmysqlclient-dev apt-utils curl rsync netcat locales
# [+] Building 8.7s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  7.3s
#  => => # Setting up mount (2.36.1-8+deb11u1) ...
#  => => # Setting up openssl (1.1.1n-0+deb11u2) ...
#  => => # Processing triggers for libc-bin (2.31-13+deb11u3) ...
#  => => # + apt-get install -yqq --no-install-recommends freetds-dev libkrb5-dev
#  => => #  libsasl2-dev libssl-dev libffi-dev libpq-dev git freetds-bin build-es
#  => => # sential default-libmysqlclient-dev apt-utils curl rsync netcat locales
# [+] Building 8.8s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  7.5s
#  => => # Setting up mount (2.36.1-8+deb11u1) ...
#  => => # Setting up openssl (1.1.1n-0+deb11u2) ...
#  => => # Processing triggers for libc-bin (2.31-13+deb11u3) ...
#  => => # + apt-get install -yqq --no-install-recommends freetds-dev libkrb5-dev
#  => => #  libsasl2-dev libssl-dev libffi-dev libpq-dev git freetds-bin build-es
#  => => # sential default-libmysqlclient-dev apt-utils curl rsync netcat locales
# [+] Building 9.0s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  7.6s
#  => => # Setting up mount (2.36.1-8+deb11u1) ...
#  => => # Setting up openssl (1.1.1n-0+deb11u2) ...
#  => => # Processing triggers for libc-bin (2.31-13+deb11u3) ...
#  => => # + apt-get install -yqq --no-install-recommends freetds-dev libkrb5-dev
#  => => #  libsasl2-dev libssl-dev libffi-dev libpq-dev git freetds-bin build-es
#  => => # sential default-libmysqlclient-dev apt-utils curl rsync netcat locales
# [+] Building 9.1s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         libk  7.8s
#  => => # Setting up mount (2.36.1-8+deb11u1) ...
#  => => # Setting up openssl (1.1.1n-0+deb11u2) ...
#  => => # Processing triggers for libc-bin (2.31-13+deb11u3) ...
#  => => # + apt-get install -yqq --no-install-recommends freetds-dev libkrb5-dev
#  => => #  libsasl2-dev libssl-dev libffi-dev libpq-dev git freetds-bin build-es
#  => => # sential default-libmysqlclient-dev apt-utils curl rsync netcat locales
# [+] Building 9.3s (3/8)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
# ...
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         lib  81.0s
#  => [3/6] COPY script/entrypoint.sh /entrypoint.sh                         0.0s
#  => [4/6] COPY config/airflow.cfg /usr/local/airflow/airflow.cfg           0.0s
#  => [5/6] RUN chown -R airflow: /usr/local/airflow                         0.4s
#  => [6/6] WORKDIR /usr/local/airflow                                       0.0s
#  => exporting to image                                                     6.4s
#  => => exporting layers                                                    6.4s
# [+] Building 89.5s (8/9)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         lib  81.0s
#  => [3/6] COPY script/entrypoint.sh /entrypoint.sh                         0.0s
#  => [4/6] COPY config/airflow.cfg /usr/local/airflow/airflow.cfg           0.0s
#  => [5/6] RUN chown -R airflow: /usr/local/airflow                         0.4s
#  => [6/6] WORKDIR /usr/local/airflow                                       0.0s
#  => exporting to image                                                     6.6s
#  => => exporting layers                                                    6.6s
# [+] Building 89.6s (8/9)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         lib  81.0s
#  => [3/6] COPY script/entrypoint.sh /entrypoint.sh                         0.0s
#  => [4/6] COPY config/airflow.cfg /usr/local/airflow/airflow.cfg           0.0s
#  => [5/6] RUN chown -R airflow: /usr/local/airflow                         0.4s
#  => [6/6] WORKDIR /usr/local/airflow                                       0.0s
#  => exporting to image                                                     6.7s
#  => => exporting layers                                                    6.7s
# [+] Building 89.8s (8/9)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         lib  81.0s
#  => [3/6] COPY script/entrypoint.sh /entrypoint.sh                         0.0s
#  => [4/6] COPY config/airflow.cfg /usr/local/airflow/airflow.cfg           0.0s
#  => [5/6] RUN chown -R airflow: /usr/local/airflow                         0.4s
#  => [6/6] WORKDIR /usr/local/airflow                                       0.0s
#  => exporting to image                                                     6.9s
#  => => exporting layers                                                    6.9s
# [+] Building 89.9s (8/9)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         lib  81.0s
#  => [3/6] COPY script/entrypoint.sh /entrypoint.sh                         0.0s
#  => [4/6] COPY config/airflow.cfg /usr/local/airflow/airflow.cfg           0.0s
#  => [5/6] RUN chown -R airflow: /usr/local/airflow                         0.4s
#  => [6/6] WORKDIR /usr/local/airflow                                       0.0s
#  => exporting to image                                                     7.0s
#  => => exporting layers                                                    7.0s
# [+] Building 90.1s (8/9)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         lib  81.0s
#  => [3/6] COPY script/entrypoint.sh /entrypoint.sh                         0.0s
#  => [4/6] COPY config/airflow.cfg /usr/local/airflow/airflow.cfg           0.0s
#  => [5/6] RUN chown -R airflow: /usr/local/airflow                         0.4s
#  => [6/6] WORKDIR /usr/local/airflow                                       0.0s
#  => exporting to image                                                     7.2s
#  => => exporting layers                                                    7.2s
# [+] Building 90.2s (8/9)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         lib  81.0s
#  => [3/6] COPY script/entrypoint.sh /entrypoint.sh                         0.0s
#  => [4/6] COPY config/airflow.cfg /usr/local/airflow/airflow.cfg           0.0s
#  => [5/6] RUN chown -R airflow: /usr/local/airflow                         0.4s
#  => [6/6] WORKDIR /usr/local/airflow                                       0.0s
#  => exporting to image                                                     7.3s
#  => => exporting layers                                                    7.3s
# [+] Building 90.4s (8/9)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         lib  81.0s
#  => [3/6] COPY script/entrypoint.sh /entrypoint.sh                         0.0s
#  => [4/6] COPY config/airflow.cfg /usr/local/airflow/airflow.cfg           0.0s
#  => [5/6] RUN chown -R airflow: /usr/local/airflow                         0.4s
#  => [6/6] WORKDIR /usr/local/airflow                                       0.0s
#  => exporting to image                                                     7.5s
#  => => exporting layers                                                    7.5s
# [+] Building 90.5s (8/9)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         lib  81.0s
#  => [3/6] COPY script/entrypoint.sh /entrypoint.sh                         0.0s
#  => [4/6] COPY config/airflow.cfg /usr/local/airflow/airflow.cfg           0.0s
#  => [5/6] RUN chown -R airflow: /usr/local/airflow                         0.4s
#  => [6/6] WORKDIR /usr/local/airflow                                       0.0s
#  => exporting to image                                                     7.6s
#  => => exporting layers                                                    7.6s
# [+] Building 90.7s (8/9)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         lib  81.0s
#  => [3/6] COPY script/entrypoint.sh /entrypoint.sh                         0.0s
#  => [4/6] COPY config/airflow.cfg /usr/local/airflow/airflow.cfg           0.0s
#  => [5/6] RUN chown -R airflow: /usr/local/airflow                         0.4s
#  => [6/6] WORKDIR /usr/local/airflow                                       0.0s
#  => exporting to image                                                     7.8s
#  => => exporting layers                                                    7.8s
# [+] Building 90.9s (8/9)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         lib  81.0s
#  => [3/6] COPY script/entrypoint.sh /entrypoint.sh                         0.0s
#  => [4/6] COPY config/airflow.cfg /usr/local/airflow/airflow.cfg           0.0s
#  => [5/6] RUN chown -R airflow: /usr/local/airflow                         0.4s
#  => [6/6] WORKDIR /usr/local/airflow                                       0.0s
#  => exporting to image                                                     7.9s
#  => => exporting layers                                                    7.9s
# [+] Building 91.0s (8/9)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         lib  81.0s
#  => [3/6] COPY script/entrypoint.sh /entrypoint.sh                         0.0s
#  => [4/6] COPY config/airflow.cfg /usr/local/airflow/airflow.cfg           0.0s
#  => [5/6] RUN chown -R airflow: /usr/local/airflow                         0.4s
#  => [6/6] WORKDIR /usr/local/airflow                                       0.0s
#  => exporting to image                                                     8.1s
#  => => exporting layers                                                    8.1s
# [+] Building 91.2s (8/9)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         lib  81.0s
#  => [3/6] COPY script/entrypoint.sh /entrypoint.sh                         0.0s
#  => [4/6] COPY config/airflow.cfg /usr/local/airflow/airflow.cfg           0.0s
#  => [5/6] RUN chown -R airflow: /usr/local/airflow                         0.4s
#  => [6/6] WORKDIR /usr/local/airflow                                       0.0s
#  => exporting to image                                                     8.2s
#  => => exporting layers                                                    8.2s
# [+] Building 91.3s (8/9)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         lib  81.0s
#  => [3/6] COPY script/entrypoint.sh /entrypoint.sh                         0.0s
#  => [4/6] COPY config/airflow.cfg /usr/local/airflow/airflow.cfg           0.0s
#  => [5/6] RUN chown -R airflow: /usr/local/airflow                         0.4s
#  => [6/6] WORKDIR /usr/local/airflow                                       0.0s
#  => exporting to image                                                     8.4s
#  => => exporting layers                                                    8.4s
# [+] Building 91.5s (8/9)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         lib  81.0s
#  => [3/6] COPY script/entrypoint.sh /entrypoint.sh                         0.0s
#  => [4/6] COPY config/airflow.cfg /usr/local/airflow/airflow.cfg           0.0s
#  => [5/6] RUN chown -R airflow: /usr/local/airflow                         0.4s
#  => [6/6] WORKDIR /usr/local/airflow                                       0.0s
#  => exporting to image                                                     8.5s
#  => => exporting layers                                                    8.5s
# [+] Building 91.6s (8/9)
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         lib  81.0s
#  => [3/6] COPY script/entrypoint.sh /entrypoint.sh                         0.0s
#  => [4/6] COPY config/airflow.cfg /usr/local/airflow/airflow.cfg           0.0s
#  => [5/6] RUN chown -R airflow: /usr/local/airflow                         0.4s
#  => [6/6] WORKDIR /usr/local/airflow                                       0.0s
#  => exporting to image                                                     8.7s
#  => => exporting layers                                                    8.7s
# [+] Building 91.7s (9/9) FINISHED
#  => CACHED [internal] load git source https://github.com/puckel/docker-ai  0.3s
#  => [internal] load metadata for docker.io/library/python:3.6-slim         0.8s
#  => CACHED [1/6] FROM docker.io/library/python:3.6-slim@sha256:2cfebc2795  0.0s
#  => [2/6] RUN set -ex     && buildDeps='         freetds-dev         lib  81.0s
#  => [3/6] COPY script/entrypoint.sh /entrypoint.sh                         0.0s
#  => [4/6] COPY config/airflow.cfg /usr/local/airflow/airflow.cfg           0.0s
#  => [5/6] RUN chown -R airflow: /usr/local/airflow                         0.4s
#  => [6/6] WORKDIR /usr/local/airflow                                       0.0s
#  => exporting to image                                                     8.8s
#  => => exporting layers                                                    8.8s
#  => => writing image sha256:5ea0c736150719a34781e1585cf47b7fbe0d1a3d5d74d  0.0s
#  => => naming to docker.io/puckel/docker-airflow:1.10.1                    0.0s
#
# Use 'docker scan' to run Snyk tests against images to find vulnerabilities and learn how to fix them
# [+] Running 1/0
#  ⠿ Container airflow-tutorial-postgres-1   Running                         0.0s
#  ⠿ Container airflow-tutorial-webserver-1  Starting                        0.1s
# [+] Running 1/2
#  ⠿ Container airflow-tutorial-postgres-1   Running                         0.0s
#  ⠿ Container airflow-tutorial-webserver-1  Starting                        0.2s
# [+] Running 1/2
#  ⠿ Container airflow-tutorial-postgres-1   Running                         0.0s
#  ⠿ Container airflow-tutorial-webserver-1  Starting                        0.3s
# [+] Running 1/2
#  ⠿ Container airflow-tutorial-postgres-1   Running                         0.0s
#  ⠿ Container airflow-tutorial-webserver-1  Starting                        0.4s
# [+] Running 2/2
#  ⠿ Container airflow-tutorial-postgres-1   Running                         0.0s
#  ⠿ Container airflow-tutorial-webserver-1  Started                         0.4s

# %%
# !docker-compose up -d
# Out:
# [+] Running 2/0
#  ⠿ Container airflow-tutorial-postgres-1   Running                         0.0s
#  ⠿ Container airflow-tutorial-webserver-1  Started                         0.0s

# %% [markdown]
# # End of this tutorial

# %%
# !cd airflow-tutorial/

# %%
# !pwd
# Out:
# /workspace/AirflowDAG

# %% [markdown]
# # new file

# %%
# !mkdir airflow-docker
# !cd airflow-docker

# %%
# !pwd
# Out:
# /workspace/AirflowDAG

# %%
curl -LfO "https://airflow.apache.org/docs/apache-airflow/stable/docker-compose.yaml"

# %%
# !mkdir ./dags ./plugins ./logs

# %%
# !docker-compose up airflow-init

# %%
# !echo -e "AIRFLOW_UID=$(id -u)\nAIRFLOW_GID=0" > .env
